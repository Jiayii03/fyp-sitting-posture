# %% [markdown]
# ## Sitting Posture Detection Training

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import f1_score, recall_score, accuracy_score
import os
import datetime
import itertools
import csv

# %% [markdown]
# ### Define Dataset class

# %%
class PostureDataset(Dataset):
    def __init__(self, data, scaler=None, label_encoder=None, from_csv=True):
        """
        Args:
        - data: CSV file path or DataFrame containing the dataset.
        - scaler: StandardScaler for feature normalization.
        - label_encoder: LabelEncoder for encoding the labels (not required if already encoded).
        - from_csv: Set to True if the input is a CSV path.
        """
        self.label_encoder = label_encoder

        # Load data
        if from_csv:
            data = pd.read_csv(data)
        
        # Ensure required columns are present
        if 'class' not in data.columns:
            raise ValueError("The input data must contain a 'class' column.")
        
        # Extract features and labels
        self.X = data.drop(columns=['class']).values  # Features
        self.y = data['class'].values  # Labels (already encoded)

        # Normalize features using StandardScaler
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            self.scaler = StandardScaler()
            self.X = self.scaler.fit_transform(self.X)
        
        self.X = torch.tensor(self.X, dtype=torch.float32)
        self.y = torch.tensor(self.y, dtype=torch.long)  # Ensure labels are integers

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %% [markdown]
# ### Define ANN Model Architecture

# %%
class MLP(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden_layers, neurons_per_layer, dropout_rate):
        super(MLP, self).__init__()
        
        # Generate a decreasing neuron configuration based on the initial size
        # For example, if neurons_per_layer=512 and num_hidden_layers=3, 
        # we'll create [512, 256, 128]
        if not isinstance(neurons_per_layer, (list, tuple)):
            initial_neurons = neurons_per_layer
            neurons_list = []
            for i in range(num_hidden_layers):
                neurons_list.append(initial_neurons // (2**i))
        else:
            neurons_list = neurons_per_layer
            
        # Create the layers list
        layers = []
        
        # First hidden layer (from input_size to first layer size)
        layers.append(nn.Linear(input_size, neurons_list[0]))
        layers.append(nn.BatchNorm1d(neurons_list[0]))
        layers.append(nn.LeakyReLU(negative_slope=0.01))
        layers.append(nn.Dropout(dropout_rate))
        
        # Additional hidden layers with different sizes
        for i in range(1, num_hidden_layers):
            layers.append(nn.Linear(neurons_list[i-1], neurons_list[i]))
            layers.append(nn.BatchNorm1d(neurons_list[i]))
            layers.append(nn.LeakyReLU(negative_slope=0.01))
            layers.append(nn.Dropout(dropout_rate))
        
        # Output layer
        layers.append(nn.Linear(neurons_list[-1], num_classes))
        
        # Create the sequential model
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Define the Training & Evaluation Function

# %%
def evaluate_model(model, data_loader, device):
    """
    Evaluates the model and returns accuracy, recall, and F1 score.
    """
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    # Calculate metrics
    accuracy = accuracy_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')
    
    return accuracy * 100, recall * 100, f1 * 100

def train_model(model, train_loader, val_loader, criterion, optimizer, epochs, patience=15):
    """
    Train the model with early stopping based on validation loss.
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    # Initialize lists to store metrics
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []
    
    # Early stopping variables
    best_val_loss = float('inf')
    early_stop_counter = 0
    
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_loss = 0
        correct_train, total_train = 0, 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_acc = correct_train / total_train
        train_losses.append(train_loss / len(train_loader))
        train_accuracies.append(train_acc)
        
        # Validation Phase
        model.eval()
        val_loss, correct_val, total_val = 0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()
        
        val_acc = correct_val / total_val
        current_val_loss = val_loss / len(val_loader)
        val_losses.append(current_val_loss)
        val_accuracies.append(val_acc)
        
        # Early stopping check
        if current_val_loss < best_val_loss:
            best_val_loss = current_val_loss
            early_stop_counter = 0
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                break
    
    return train_losses, train_accuracies, val_losses, val_accuracies

# %% [markdown]
# ### Defining Dataset Loading Function

# %%
# Load and preprocess data
def load_and_prepare_data(csv_path):
    """
    Load the dataset, encode labels, and prepare for training.
    """
    df = pd.read_csv(csv_path)  
    
    print("Number of samples per class before train test split:")
    print(df['class'].value_counts())
    
    # Encode class labels to integers using LabelEncoder
    label_encoder = LabelEncoder()
    df['class'] = label_encoder.fit_transform(df['class'])
    
    # Split the data into training and test datasets
    RANDOM_SEED = 42
    torch.manual_seed(RANDOM_SEED)
    torch.cuda.manual_seed(RANDOM_SEED)
    
    train_data, test_data = train_test_split(df, test_size=0.3, random_state=RANDOM_SEED)
    
    # Standardize features
    scaler = StandardScaler()
    train_features = train_data.drop(columns=['class']).values
    scaler.fit(train_features)
    
    return train_data, test_data, scaler, label_encoder

# %% [markdown]
# ### Function to run single experiment

# %%
def run_experiment(hyperparams, train_data, test_data, scaler, label_encoder, exp_id, num_classes=4):
    """
    Run a single experiment with the given hyperparameters and return the results.
    """
    # Extract hyperparameters
    learning_rate = hyperparams['learning_rate']
    num_hidden_layers = hyperparams['num_hidden_layers']
    neurons_per_layer = hyperparams['neurons_per_layer']
    dropout_rate = hyperparams['dropout_rate']
    batch_size = hyperparams['batch_size']
    epochs = hyperparams['epochs']
    
    # Create datasets and loaders
    train_dataset = PostureDataset(train_data, scaler=scaler, label_encoder=label_encoder, from_csv=False)
    test_dataset = PostureDataset(test_data, scaler=scaler, label_encoder=label_encoder, from_csv=False)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    # Model initialization
    input_size = train_data.drop(columns=['class']).shape[1]
    
    model = MLP(input_size, num_classes, num_hidden_layers, neurons_per_layer, dropout_rate)
    
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.005)
    
    # Train the model
    train_losses, train_accuracies, val_losses, val_accuracies = train_model(
        model, train_loader, test_loader, criterion, optimizer, epochs
    )
    
    # Evaluate the model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    accuracy, recall, f1 = evaluate_model(model, test_loader, device)
    
    # Store metrics
    metrics = {
        'accuracy': accuracy,
        'recall': recall,
        'f1_score': f1,
        'best_val_loss': min(val_losses),
        'best_val_accuracy': max(val_accuracies)
    }
    
    return metrics

# %% [markdown]
# ### Defining the Grid Search Function

# %%
def hyperparameter_grid_search(grid, train_data, test_data, scaler, label_encoder, csv_file='../experiments/tuning/tuning_results.csv'):
    """
    Perform a grid search over the hyperparameter space and save only the CSV results.
    """
    # Create directory for the CSV if needed
    os.makedirs(os.path.dirname(os.path.abspath(csv_file)) if os.path.dirname(csv_file) else '.', exist_ok=True)
    
    # Define CSV headers
    headers = [
        'Experiment', 'Number of Layers', 'Neurons per Layer', 'Learning Rate',
        'Dropout Rate', 'Batch Size', 'Epochs', 'Optimizer', 'Accuracy', 'Recall', 'Value F1'
    ]
    
    # Write the header row with explicit UTF-8 encoding
    with open(csv_file, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(headers)
    
    # Generate all combinations of hyperparameters
    keys = grid.keys()
    values = grid.values()
    combinations = list(itertools.product(*values))
    total_experiments = len(combinations)
    
    # Run each experiment
    results = []
    
    print(f"Starting grid search with {total_experiments} experiments...")
    
    for i, combo in enumerate(combinations):
        # Create hyperparameter dictionary
        hyperparams = dict(zip(keys, combo))
        
        # Create experiment ID
        exp_id = f"Exp-{i+1}"
        
        # Generate the decreasing neuron configuration
        initial_neurons = hyperparams['neurons_per_layer']

        # Add this check to handle if initial_neurons is already a list
        if isinstance(initial_neurons, (list, tuple)):
            neuron_config = initial_neurons  # Use it directly
        else:
            # Otherwise, generate decreasing neuron pattern
            num_layers = hyperparams['num_hidden_layers']
            neuron_config = []
            for j in range(num_layers):
                neuron_config.append(initial_neurons // (2**j))
        
        # Store the complete neuron configuration
        hyperparams['neuron_config'] = neuron_config
        
        # Print progress info
        print(f"Running {exp_id} of {total_experiments} ({(i+1)/total_experiments*100:.1f}%)")
        
        # Run the experiment
        metrics = run_experiment(
            hyperparams, train_data, test_data, 
            scaler, label_encoder, exp_id
        )
        
        # Prepare row for CSV
        row = [
            exp_id,
            hyperparams['num_hidden_layers'],
            str(neuron_config),  # Store as string representation of list
            hyperparams['learning_rate'],
            hyperparams['dropout_rate'],
            hyperparams['batch_size'],
            hyperparams['epochs'],
            'Adam',  # Fixed to Adam
            f"{metrics['accuracy']:.2f}",
            f"{metrics['recall']:.2f}",
            f"{metrics['f1_score']:.2f}"
        ]
        
        # Write the results to the CSV file with explicit UTF-8 encoding
        with open(csv_file, 'a', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(row)
        
        # Store results
        results.append({
            'hyperparams': hyperparams,
            'metrics': metrics
        })
        
        # Print results for this experiment
        print(f"Results for {exp_id}: Accuracy={metrics['accuracy']:.2f}%, Recall={metrics['recall']:.2f}%, F1={metrics['f1_score']:.2f}%")
        print("-" * 40)
    
    return results, csv_file

# %% [markdown]
# ### Function to visualise hyperparameter results

# %%
def visualize_hyperparameter_results(csv_file, output_dir='../experiments/tuning'):
    """
    Visualize the hyperparameter tuning results in a more compact way.
    Creates heatmaps and bar charts to display the results.
    """
    import matplotlib.pyplot as plt
    import seaborn as sns
    import pandas as pd
    import os
    import numpy as np
    
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Load results
    results = pd.read_csv(csv_file)
    
    # Convert string metrics to numeric
    for col in ['Accuracy', 'Recall', 'Value F1']:
        results[col] = pd.to_numeric(results[col])
    
    # 1. Top Performers Table - show only top 15 results sorted by accuracy
    top_performers = results.sort_values('Accuracy', ascending=False).head(15)
    print("Top 15 Configurations by Accuracy:")
    print(top_performers)
    
    # Save top performers to CSV
    top_performers.to_csv(os.path.join(output_dir, 'top_performers.csv'), index=False)
    
    # ---------- VISUALIZATIONS ----------
    
    # 2. Create plots in a 2x3 grid
    plt.figure(figsize=(20, 15))
    
    # 2.1 Learning Rate vs Dropout Rate (with accuracy as color)
    plt.subplot(2, 3, 1)
    pivot = results.pivot_table(
        values='Accuracy', 
        index='Learning Rate',
        columns='Dropout Rate', 
        aggfunc='mean'
    )
    sns.heatmap(pivot, annot=True, cmap='YlGnBu', fmt='.1f')
    plt.title('Mean Accuracy by Learning Rate and Dropout Rate')
    
    # 2.2 Learning Rate vs Number of Layers
    plt.subplot(2, 3, 2)
    pivot = results.pivot_table(
        values='Accuracy', 
        index='Learning Rate',
        columns='Number of Layers', 
        aggfunc='mean'
    )
    sns.heatmap(pivot, annot=True, cmap='YlGnBu', fmt='.1f')
    plt.title('Mean Accuracy by Learning Rate and Network Depth')
    
    # 2.3 Epochs vs Number of Layers
    plt.subplot(2, 3, 3)
    pivot = results.pivot_table(
        values='Accuracy', 
        index='Epochs',
        columns='Number of Layers', 
        aggfunc='mean'
    )
    sns.heatmap(pivot, annot=True, cmap='YlGnBu', fmt='.1f')
    plt.title('Mean Accuracy by Epochs and Network Depth')
    
    # 2.4 Bar chart of metrics by Number of Layers
    plt.subplot(2, 3, 4)
    metrics_by_layers = results.groupby('Number of Layers')[['Accuracy', 'Recall', 'Value F1']].mean().reset_index()
    metrics_by_layers.plot(x='Number of Layers', kind='bar', ax=plt.gca())
    plt.title('Performance Metrics by Network Depth')
    plt.ylabel('Score')
    plt.xticks(rotation=0)
    
    # 2.5 Bar chart of metrics by Learning Rate
    plt.subplot(2, 3, 5)
    metrics_by_lr = results.groupby('Learning Rate')[['Accuracy', 'Recall', 'Value F1']].mean().reset_index()
    metrics_by_lr.plot(x='Learning Rate', kind='bar', ax=plt.gca())
    plt.title('Performance Metrics by Learning Rate')
    plt.ylabel('Score')
    plt.xticks(rotation=0)
    
    # 2.6 Bar chart of metrics by Epochs
    plt.subplot(2, 3, 6)
    metrics_by_epochs = results.groupby('Epochs')[['Accuracy', 'Recall', 'Value F1']].mean().reset_index()
    metrics_by_epochs.plot(x='Epochs', kind='bar', ax=plt.gca())
    plt.title('Performance Metrics by Epochs')
    plt.ylabel('Score')
    plt.xticks(rotation=0)
    
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'hyperparameter_visualization_grid.png'))
    plt.close()
    
    # 3. Network architectures comparison
    plt.figure(figsize=(14, 8))
    
    # Create a more readable representation of network architecture
    results['Network Architecture'] = results.apply(
        lambda row: f"{row['Number of Layers']}L: {row['Neurons per Layer']}", axis=1
    )
    
    # Get top 2 performing architectures for each depth
    top_archs = []
    for depth in results['Number of Layers'].unique():
        filtered = results[results['Number of Layers'] == depth]
        best_archs = filtered.groupby('Neurons per Layer')['Accuracy'].mean().nlargest(1).index.tolist()
        for arch in best_archs:
            top_archs.append((depth, arch))
    
    # Filter results to only include top architectures
    filtered_results = results[results.apply(
        lambda row: (row['Number of Layers'], row['Neurons per Layer']) in top_archs, axis=1
    )]
    
    # Get mean metrics for each architecture
    arch_metrics = filtered_results.groupby('Network Architecture')[['Accuracy', 'Recall', 'Value F1']].mean()
    
    # Sort by accuracy
    arch_metrics = arch_metrics.sort_values('Accuracy', ascending=False)
    
    # Plot
    arch_metrics.plot(kind='barh', figsize=(10, 8))
    plt.title('Performance Comparison of Top Network Architectures')
    plt.xlabel('Score')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'network_architecture_comparison.png'))
    plt.close()
    
    # 4. Learning curves - Accuracy vs Epochs for different configurations
    plt.figure(figsize=(14, 8))
    
    # Group by epochs and compute mean, min, max
    epoch_stats = results.groupby('Epochs')[['Accuracy', 'Recall', 'Value F1']].agg(['mean', 'min', 'max'])
    
    # Plot accuracy vs epochs with error bars
    x = np.array(epoch_stats.index)
    y = epoch_stats['Accuracy']['mean'].values
    min_vals = epoch_stats['Accuracy']['min'].values
    max_vals = epoch_stats['Accuracy']['max'].values
    
    plt.errorbar(x, y, yerr=[y-min_vals, max_vals-y], fmt='-o', capsize=5, label='Accuracy')
    
    # Plot recall and F1 as well
    plt.plot(x, epoch_stats['Recall']['mean'].values, 's-', label='Recall')
    plt.plot(x, epoch_stats['Value F1']['mean'].values, '^-', label='F1 Score')
    
    plt.xlabel('Epochs')
    plt.ylabel('Score')
    plt.title('Performance Metrics vs Training Epochs')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.savefig(os.path.join(output_dir, 'epoch_performance.png'))
    plt.close()
    
    # 5. Parameter importance analysis
    plt.figure(figsize=(12, 8))
    
    # Compute variance in accuracy for each parameter
    param_variance = {}
    for param in ['Learning Rate', 'Number of Layers', 'Dropout Rate', 'Epochs']:
        param_variance[param] = results.groupby(param)['Accuracy'].mean().var()
    
    # Convert to DataFrame and sort
    param_var_df = pd.DataFrame.from_dict(param_variance, orient='index', columns=['Variance'])
    param_var_df = param_var_df.sort_values('Variance', ascending=False)
    
    # Plot
    param_var_df.plot(kind='bar', figsize=(10, 6))
    plt.title('Hyperparameter Importance (Higher Variance = More Impact)')
    plt.ylabel('Variance in Accuracy')
    plt.xlabel('Hyperparameter')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'parameter_importance.png'))
    plt.close()
    
    # 6. Create a table-like visualization summarizing the best configurations
    plt.figure(figsize=(12, 8))
    
    # Get top configurations for each metric
    top_configs = {
        'Accuracy': results.sort_values('Accuracy', ascending=False).iloc[0],
        'Recall': results.sort_values('Recall', ascending=False).iloc[0],
        'F1 Score': results.sort_values('Value F1', ascending=False).iloc[0]
    }
    
    # Create table data
    table_data = [
        [metric, 
         f"{config['Learning Rate']}", 
         f"{config['Number of Layers']}", 
         f"{config['Neurons per Layer']}", 
         f"{config['Dropout Rate']}", 
         f"{config['Epochs']}", 
         f"{config['Accuracy']:.2f}", 
         f"{config['Recall']:.2f}", 
         f"{config['Value F1']:.2f}"]
        for metric, config in top_configs.items()
    ]
    
    # Create table
    ax = plt.gca()
    ax.axis('off')
    table = ax.table(
        cellText=table_data,
        colLabels=['Optimized For', 'LR', 'Layers', 'Neurons', 'Dropout', 'Epochs', 'Accuracy', 'Recall', 'F1'],
        loc='center',
        cellLoc='center'
    )
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1.2, 1.5)
    
    plt.title('Best Configurations by Metric', y=0.8)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'best_configs_table.png'))
    plt.close()
    
    print(f"Visualizations saved to {output_dir}")
    
    # Return detailed statistics for further analysis
    return {
        'top_by_accuracy': results.sort_values('Accuracy', ascending=False).head(5),
        'top_by_f1': results.sort_values('Value F1', ascending=False).head(5),
        'top_by_recall': results.sort_values('Recall', ascending=False).head(5),
        'mean_by_lr': results.groupby('Learning Rate')['Accuracy'].mean(),
        'mean_by_layers': results.groupby('Number of Layers')['Accuracy'].mean(),
        'mean_by_dropout': results.groupby('Dropout Rate')['Accuracy'].mean(),
        'mean_by_epochs': results.groupby('Epochs')['Accuracy'].mean(),
    }

# %% [markdown]
# ### Main Execution Function

# %%
# Main execution function
def main():
    # Define the hyperparameter grid
    hyperparameter_grid = {
        'learning_rate': [0.001, 0.0005, 0.0001],
        'num_hidden_layers': [2, 3, 4],
        'neurons_per_layer': [128, 256, 512],
        'dropout_rate': [0.3, 0.5, 0.7],
        'batch_size': [16, 32],
        'epochs': [100, 200, 300]
    }

    # Alternative simplified grid for faster testing
    simplified_grid = {
        'learning_rate': [0.001],
        'num_hidden_layers': [3],
        'neurons_per_layer': [[512, 256, 128]],
        'dropout_rate': [0.4],
        'batch_size': [32],
        'epochs': [100],
        'optimizer': ['Adam']
    }

    # Load and prepare data
    csv_path = "../../datasets/vectors/augmented_xy_filtered_keypoints_vectors_mediapipe.csv"
    train_data, test_data, scaler, label_encoder = load_and_prepare_data(
        csv_path)

    # Run grid search with simplified grid (for testing)
    # results, csv_file = hyperparameter_grid_search(simplified_grid, train_data, test_data, scaler, label_encoder)

    # For the full grid, uncomment this line
    results, csv_file = hyperparameter_grid_search(
        hyperparameter_grid, train_data, test_data, scaler, label_encoder)

    print(f"All experiments completed. Results saved to {csv_file}")

    # Load the results as a DataFrame and display
    df_results = pd.read_csv(csv_file)
    print(df_results)
    
    # Visualize results
    print("\nCreating visualizations...")
    stats = visualize_hyperparameter_results(csv_file)
    
    print("\nTop 5 configurations by accuracy:")
    print(stats['top_by_accuracy'])
    
    print("\nMean accuracy by parameter:")
    print("Learning Rate:", stats['mean_by_lr'])
    print("Network Depth:", stats['mean_by_layers'])
    print("Dropout Rate:", stats['mean_by_dropout'])
    print("Epochs:", stats['mean_by_epochs'])


if __name__ == "__main__":
    main()
# Out:
# Number of samples per class before train test split:
# class
# crossed_legs    1091
# proper          1084
# slouching       1000
# reclining        970
# Name: count, dtype: int64
# Starting grid search with 486 experiments...
# Running Exp-1 of 486 (0.2%)
# Results for Exp-1: Accuracy=81.43%, Recall=81.29%, F1=81.38%
# ----------------------------------------
# Running Exp-2 of 486 (0.4%)
# Results for Exp-2: Accuracy=81.75%, Recall=81.41%, F1=81.59%
# ----------------------------------------
# Running Exp-3 of 486 (0.6%)
# Results for Exp-3: Accuracy=81.75%, Recall=81.58%, F1=81.56%
# ----------------------------------------
# Running Exp-4 of 486 (0.8%)
# Results for Exp-4: Accuracy=84.57%, Recall=84.54%, F1=84.42%
# ----------------------------------------
# Running Exp-5 of 486 (1.0%)
# Results for Exp-5: Accuracy=84.32%, Recall=84.11%, F1=84.18%
# ----------------------------------------
# Running Exp-6 of 486 (1.2%)
# Results for Exp-6: Accuracy=84.16%, Recall=84.02%, F1=84.02%
# ----------------------------------------
# Running Exp-7 of 486 (1.4%)
# Results for Exp-7: Accuracy=81.27%, Recall=81.06%, F1=81.02%
# ----------------------------------------
# Running Exp-8 of 486 (1.6%)
# Results for Exp-8: Accuracy=82.80%, Recall=82.64%, F1=82.66%
# ----------------------------------------
# Running Exp-9 of 486 (1.9%)
# Results for Exp-9: Accuracy=81.43%, Recall=81.27%, F1=81.16%
# ----------------------------------------
# Running Exp-10 of 486 (2.1%)
# Results for Exp-10: Accuracy=83.04%, Recall=82.89%, F1=82.91%
# ----------------------------------------
# Running Exp-11 of 486 (2.3%)
# Results for Exp-11: Accuracy=83.04%, Recall=82.93%, F1=82.90%
# ----------------------------------------
# Running Exp-12 of 486 (2.5%)
# Results for Exp-12: Accuracy=81.75%, Recall=81.74%, F1=81.69%
# ----------------------------------------
# Running Exp-13 of 486 (2.7%)
# Results for Exp-13: Accuracy=78.46%, Recall=78.05%, F1=78.20%
# ----------------------------------------
# Running Exp-14 of 486 (2.9%)
# Results for Exp-14: Accuracy=77.49%, Recall=77.20%, F1=77.09%
# ----------------------------------------
# Running Exp-15 of 486 (3.1%)
# Results for Exp-15: Accuracy=78.70%, Recall=78.32%, F1=78.38%
# ----------------------------------------
# Running Exp-16 of 486 (3.3%)
# Results for Exp-16: Accuracy=80.47%, Recall=80.60%, F1=80.25%
# ----------------------------------------
# Running Exp-17 of 486 (3.5%)
# Results for Exp-17: Accuracy=79.42%, Recall=79.48%, F1=79.10%
# ----------------------------------------
# Running Exp-18 of 486 (3.7%)
# Results for Exp-18: Accuracy=81.03%, Recall=81.02%, F1=80.90%
# ----------------------------------------
# Running Exp-19 of 486 (3.9%)
# Results for Exp-19: Accuracy=82.72%, Recall=82.90%, F1=82.39%
# ----------------------------------------
# Running Exp-20 of 486 (4.1%)
# Results for Exp-20: Accuracy=82.56%, Recall=82.58%, F1=82.58%
# ----------------------------------------
# Running Exp-21 of 486 (4.3%)
# Results for Exp-21: Accuracy=83.04%, Recall=82.88%, F1=82.87%
# ----------------------------------------
# Running Exp-22 of 486 (4.5%)
# Results for Exp-22: Accuracy=84.16%, Recall=84.25%, F1=84.04%
# ----------------------------------------
# Running Exp-23 of 486 (4.7%)
# Results for Exp-23: Accuracy=83.92%, Recall=83.74%, F1=83.79%
# ----------------------------------------
# Running Exp-24 of 486 (4.9%)
# Results for Exp-24: Accuracy=83.68%, Recall=83.67%, F1=83.58%
# ----------------------------------------
# Running Exp-25 of 486 (5.1%)
# Results for Exp-25: Accuracy=81.27%, Recall=81.29%, F1=80.98%
# ----------------------------------------
# Running Exp-26 of 486 (5.3%)
# Results for Exp-26: Accuracy=81.67%, Recall=81.79%, F1=81.30%
# ----------------------------------------
# Running Exp-27 of 486 (5.6%)
# Results for Exp-27: Accuracy=81.03%, Recall=80.86%, F1=80.82%
# ----------------------------------------
# Running Exp-28 of 486 (5.8%)
# Results for Exp-28: Accuracy=84.41%, Recall=84.22%, F1=84.38%
# ----------------------------------------
# Running Exp-29 of 486 (6.0%)
# Results for Exp-29: Accuracy=82.80%, Recall=82.89%, F1=82.48%
# ----------------------------------------
# Running Exp-30 of 486 (6.2%)
# Results for Exp-30: Accuracy=82.23%, Recall=82.40%, F1=81.71%
# ----------------------------------------
# Running Exp-31 of 486 (6.4%)
# Results for Exp-31: Accuracy=77.81%, Recall=77.52%, F1=77.53%
# ----------------------------------------
# Running Exp-32 of 486 (6.6%)
# Results for Exp-32: Accuracy=78.94%, Recall=78.64%, F1=78.76%
# ----------------------------------------
# Running Exp-33 of 486 (6.8%)
# Results for Exp-33: Accuracy=78.14%, Recall=77.92%, F1=77.78%
# ----------------------------------------
# Running Exp-34 of 486 (7.0%)
# Results for Exp-34: Accuracy=83.60%, Recall=83.77%, F1=83.60%
# ----------------------------------------
# Running Exp-35 of 486 (7.2%)
# Results for Exp-35: Accuracy=81.11%, Recall=81.19%, F1=80.82%
# ----------------------------------------
# Running Exp-36 of 486 (7.4%)
# Results for Exp-36: Accuracy=81.99%, Recall=81.81%, F1=81.87%
# ----------------------------------------
# Running Exp-37 of 486 (7.6%)
# Results for Exp-37: Accuracy=80.87%, Recall=80.31%, F1=80.66%
# ----------------------------------------
# Running Exp-38 of 486 (7.8%)
# Results for Exp-38: Accuracy=82.80%, Recall=82.63%, F1=82.65%
# ----------------------------------------
# Running Exp-39 of 486 (8.0%)
# Results for Exp-39: Accuracy=81.43%, Recall=81.02%, F1=81.23%
# ----------------------------------------
# Running Exp-40 of 486 (8.2%)
# Results for Exp-40: Accuracy=84.08%, Recall=83.88%, F1=83.87%
# ----------------------------------------
# Running Exp-41 of 486 (8.4%)
# Results for Exp-41: Accuracy=84.65%, Recall=84.88%, F1=84.45%
# ----------------------------------------
# Running Exp-42 of 486 (8.6%)
# Results for Exp-42: Accuracy=83.68%, Recall=83.61%, F1=83.62%
# ----------------------------------------
# Running Exp-43 of 486 (8.8%)
# Results for Exp-43: Accuracy=80.95%, Recall=80.50%, F1=80.77%
# ----------------------------------------
# Running Exp-44 of 486 (9.1%)
# Results for Exp-44: Accuracy=82.15%, Recall=82.08%, F1=82.00%
# ----------------------------------------
# Running Exp-45 of 486 (9.3%)
# Results for Exp-45: Accuracy=80.55%, Recall=80.31%, F1=80.25%
# ----------------------------------------
# Running Exp-46 of 486 (9.5%)
# Results for Exp-46: Accuracy=82.64%, Recall=82.56%, F1=82.43%
# ----------------------------------------
# Running Exp-47 of 486 (9.7%)
# Results for Exp-47: Accuracy=83.04%, Recall=82.76%, F1=83.00%
# ----------------------------------------
# Running Exp-48 of 486 (9.9%)
# Results for Exp-48: Accuracy=83.92%, Recall=83.89%, F1=83.80%
# ----------------------------------------
# Running Exp-49 of 486 (10.1%)
# Results for Exp-49: Accuracy=79.10%, Recall=78.72%, F1=78.86%
# ----------------------------------------
# Running Exp-50 of 486 (10.3%)
# Results for Exp-50: Accuracy=78.94%, Recall=78.66%, F1=78.67%
# ----------------------------------------
# Running Exp-51 of 486 (10.5%)
# Results for Exp-51: Accuracy=78.86%, Recall=78.28%, F1=78.66%
# ----------------------------------------
# Running Exp-52 of 486 (10.7%)
# Results for Exp-52: Accuracy=82.32%, Recall=82.15%, F1=82.11%
# ----------------------------------------
# Running Exp-53 of 486 (10.9%)
# Results for Exp-53: Accuracy=81.75%, Recall=81.61%, F1=81.65%
# ----------------------------------------
# Running Exp-54 of 486 (11.1%)
# Results for Exp-54: Accuracy=80.95%, Recall=80.94%, F1=80.69%
# ----------------------------------------
# Running Exp-55 of 486 (11.3%)
# Results for Exp-55: Accuracy=82.72%, Recall=82.47%, F1=82.63%
# ----------------------------------------
# Running Exp-56 of 486 (11.5%)
# Results for Exp-56: Accuracy=81.75%, Recall=81.30%, F1=81.60%
# ----------------------------------------
# Running Exp-57 of 486 (11.7%)
# Results for Exp-57: Accuracy=83.04%, Recall=82.66%, F1=82.92%
# ----------------------------------------
# Running Exp-58 of 486 (11.9%)
# Results for Exp-58: Accuracy=84.49%, Recall=84.18%, F1=84.23%
# ----------------------------------------
# Running Exp-59 of 486 (12.1%)
# Results for Exp-59: Accuracy=83.52%, Recall=83.33%, F1=83.20%
# ----------------------------------------
# Running Exp-60 of 486 (12.3%)
# Results for Exp-60: Accuracy=85.53%, Recall=85.67%, F1=85.49%
# ----------------------------------------
# Running Exp-61 of 486 (12.6%)
# Results for Exp-61: Accuracy=79.66%, Recall=79.91%, F1=79.30%
# ----------------------------------------
# Running Exp-62 of 486 (12.8%)
# Results for Exp-62: Accuracy=81.03%, Recall=81.11%, F1=80.98%
# ----------------------------------------
# Running Exp-63 of 486 (13.0%)
# Results for Exp-63: Accuracy=80.06%, Recall=79.62%, F1=79.82%
# ----------------------------------------
# Running Exp-64 of 486 (13.2%)
# Results for Exp-64: Accuracy=82.48%, Recall=82.47%, F1=82.27%
# ----------------------------------------
# Running Exp-65 of 486 (13.4%)
# Results for Exp-65: Accuracy=81.67%, Recall=81.94%, F1=81.65%
# ----------------------------------------
# Running Exp-66 of 486 (13.6%)
# Results for Exp-66: Accuracy=82.72%, Recall=82.70%, F1=82.66%
# ----------------------------------------
# Running Exp-67 of 486 (13.8%)
# Results for Exp-67: Accuracy=75.64%, Recall=75.37%, F1=74.97%
# ----------------------------------------
# Running Exp-68 of 486 (14.0%)
# Results for Exp-68: Accuracy=73.07%, Recall=72.88%, F1=71.92%
# ----------------------------------------
# Running Exp-69 of 486 (14.2%)
# Results for Exp-69: Accuracy=72.91%, Recall=72.83%, F1=71.32%
# ----------------------------------------
# Running Exp-70 of 486 (14.4%)
# Results for Exp-70: Accuracy=78.70%, Recall=78.86%, F1=78.27%
# ----------------------------------------
# Running Exp-71 of 486 (14.6%)
# Results for Exp-71: Accuracy=78.46%, Recall=78.54%, F1=78.18%
# ----------------------------------------
# Running Exp-72 of 486 (14.8%)
# Results for Exp-72: Accuracy=77.89%, Recall=77.83%, F1=77.45%
# ----------------------------------------
# Running Exp-73 of 486 (15.0%)
# Results for Exp-73: Accuracy=82.23%, Recall=81.90%, F1=82.05%
# ----------------------------------------
# Running Exp-74 of 486 (15.2%)
# Results for Exp-74: Accuracy=83.68%, Recall=83.74%, F1=83.58%
# ----------------------------------------
# Running Exp-75 of 486 (15.4%)
# Results for Exp-75: Accuracy=81.19%, Recall=81.08%, F1=80.97%
# ----------------------------------------
# Running Exp-76 of 486 (15.6%)
# Results for Exp-76: Accuracy=85.21%, Recall=84.96%, F1=85.14%
# ----------------------------------------
# Running Exp-77 of 486 (15.8%)
# Results for Exp-77: Accuracy=84.41%, Recall=84.32%, F1=84.37%
# ----------------------------------------
# Running Exp-78 of 486 (16.0%)
# Results for Exp-78: Accuracy=84.97%, Recall=84.85%, F1=84.81%
# ----------------------------------------
# Running Exp-79 of 486 (16.3%)
# Results for Exp-79: Accuracy=81.11%, Recall=81.17%, F1=80.78%
# ----------------------------------------
# Running Exp-80 of 486 (16.5%)
# Results for Exp-80: Accuracy=81.83%, Recall=81.66%, F1=81.71%
# ----------------------------------------
# Running Exp-81 of 486 (16.7%)
# Results for Exp-81: Accuracy=80.47%, Recall=80.13%, F1=80.36%
# ----------------------------------------
# Running Exp-82 of 486 (16.9%)
# Results for Exp-82: Accuracy=83.68%, Recall=83.55%, F1=83.63%
# ----------------------------------------
# Running Exp-83 of 486 (17.1%)
# Results for Exp-83: Accuracy=83.04%, Recall=82.85%, F1=82.97%
# ----------------------------------------
# Running Exp-84 of 486 (17.3%)
# Results for Exp-84: Accuracy=84.49%, Recall=84.60%, F1=84.35%
# ----------------------------------------
# Running Exp-85 of 486 (17.5%)
# Results for Exp-85: Accuracy=78.78%, Recall=78.42%, F1=78.53%
# ----------------------------------------
# Running Exp-86 of 486 (17.7%)
# Results for Exp-86: Accuracy=77.97%, Recall=77.82%, F1=77.37%
# ----------------------------------------
# Running Exp-87 of 486 (17.9%)
# Results for Exp-87: Accuracy=79.66%, Recall=79.58%, F1=79.18%
# ----------------------------------------
# Running Exp-88 of 486 (18.1%)
# Results for Exp-88: Accuracy=80.79%, Recall=80.64%, F1=80.77%
# ----------------------------------------
# Running Exp-89 of 486 (18.3%)
# Results for Exp-89: Accuracy=82.48%, Recall=82.52%, F1=82.40%
# ----------------------------------------
# Running Exp-90 of 486 (18.5%)
# Results for Exp-90: Accuracy=81.91%, Recall=81.93%, F1=82.00%
# ----------------------------------------
# Running Exp-91 of 486 (18.7%)
# Results for Exp-91: Accuracy=81.99%, Recall=81.76%, F1=81.88%
# ----------------------------------------
# Running Exp-92 of 486 (18.9%)
# Results for Exp-92: Accuracy=83.20%, Recall=83.41%, F1=83.06%
# ----------------------------------------
# Running Exp-93 of 486 (19.1%)
# Results for Exp-93: Accuracy=82.96%, Recall=83.06%, F1=82.88%
# ----------------------------------------
# Running Exp-94 of 486 (19.3%)
# Results for Exp-94: Accuracy=83.84%, Recall=83.49%, F1=83.78%
# ----------------------------------------
# Running Exp-95 of 486 (19.5%)
# Results for Exp-95: Accuracy=84.24%, Recall=84.17%, F1=84.12%
# ----------------------------------------
# Running Exp-96 of 486 (19.8%)
# Results for Exp-96: Accuracy=84.65%, Recall=84.67%, F1=84.51%
# ----------------------------------------
# Running Exp-97 of 486 (20.0%)
# Results for Exp-97: Accuracy=81.59%, Recall=81.44%, F1=81.53%
# ----------------------------------------
# Running Exp-98 of 486 (20.2%)
# Results for Exp-98: Accuracy=80.71%, Recall=80.72%, F1=80.44%
# ----------------------------------------
# Running Exp-99 of 486 (20.4%)
# Results for Exp-99: Accuracy=80.23%, Recall=79.90%, F1=80.03%
# ----------------------------------------
# Running Exp-100 of 486 (20.6%)
# Results for Exp-100: Accuracy=82.80%, Recall=82.59%, F1=82.72%
# ----------------------------------------
# Running Exp-101 of 486 (20.8%)
# Results for Exp-101: Accuracy=82.48%, Recall=82.36%, F1=82.26%
# ----------------------------------------
# Running Exp-102 of 486 (21.0%)
# Results for Exp-102: Accuracy=84.81%, Recall=84.63%, F1=84.69%
# ----------------------------------------
# Running Exp-103 of 486 (21.2%)
# Results for Exp-103: Accuracy=77.57%, Recall=77.03%, F1=77.30%
# ----------------------------------------
# Running Exp-104 of 486 (21.4%)
# Results for Exp-104: Accuracy=78.86%, Recall=78.77%, F1=78.44%
# ----------------------------------------
# Running Exp-105 of 486 (21.6%)
# Results for Exp-105: Accuracy=78.30%, Recall=77.95%, F1=78.18%
# ----------------------------------------
# Running Exp-106 of 486 (21.8%)
# Results for Exp-106: Accuracy=80.55%, Recall=80.63%, F1=80.16%
# ----------------------------------------
# Running Exp-107 of 486 (22.0%)
# Results for Exp-107: Accuracy=80.14%, Recall=80.24%, F1=79.92%
# ----------------------------------------
# Running Exp-108 of 486 (22.2%)
# Results for Exp-108: Accuracy=81.75%, Recall=81.96%, F1=81.60%
# ----------------------------------------
# Running Exp-109 of 486 (22.4%)
# Results for Exp-109: Accuracy=81.99%, Recall=82.09%, F1=81.82%
# ----------------------------------------
# Running Exp-110 of 486 (22.6%)
# Results for Exp-110: Accuracy=82.23%, Recall=82.04%, F1=82.16%
# ----------------------------------------
# Running Exp-111 of 486 (22.8%)
# Results for Exp-111: Accuracy=81.83%, Recall=81.83%, F1=81.66%
# ----------------------------------------
# Running Exp-112 of 486 (23.0%)
# Results for Exp-112: Accuracy=84.08%, Recall=84.18%, F1=83.97%
# ----------------------------------------
# Running Exp-113 of 486 (23.3%)
# Results for Exp-113: Accuracy=83.60%, Recall=83.68%, F1=83.51%
# ----------------------------------------
# Running Exp-114 of 486 (23.5%)
# Results for Exp-114: Accuracy=84.49%, Recall=84.51%, F1=84.36%
# ----------------------------------------
# Running Exp-115 of 486 (23.7%)
# Results for Exp-115: Accuracy=78.22%, Recall=78.14%, F1=77.55%
# ----------------------------------------
# Running Exp-116 of 486 (23.9%)
# Results for Exp-116: Accuracy=77.41%, Recall=77.81%, F1=76.77%
# ----------------------------------------
# Running Exp-117 of 486 (24.1%)
# Results for Exp-117: Accuracy=78.05%, Recall=77.67%, F1=77.77%
# ----------------------------------------
# Running Exp-118 of 486 (24.3%)
# Results for Exp-118: Accuracy=80.06%, Recall=80.39%, F1=79.65%
# ----------------------------------------
# Running Exp-119 of 486 (24.5%)
# Results for Exp-119: Accuracy=81.91%, Recall=82.36%, F1=81.61%
# ----------------------------------------
# Running Exp-120 of 486 (24.7%)
# Results for Exp-120: Accuracy=80.95%, Recall=81.16%, F1=80.82%
# ----------------------------------------
# Running Exp-121 of 486 (24.9%)
# Results for Exp-121: Accuracy=68.33%, Recall=67.37%, F1=67.19%
# ----------------------------------------
# Running Exp-122 of 486 (25.1%)
# Results for Exp-122: Accuracy=69.86%, Recall=69.41%, F1=68.33%
# ----------------------------------------
# Running Exp-123 of 486 (25.3%)
# Results for Exp-123: Accuracy=71.70%, Recall=71.67%, F1=70.13%
# ----------------------------------------
# Running Exp-124 of 486 (25.5%)
# Results for Exp-124: Accuracy=73.15%, Recall=72.84%, F1=72.27%
# ----------------------------------------
# Running Exp-125 of 486 (25.7%)
# Results for Exp-125: Accuracy=70.18%, Recall=70.72%, F1=68.24%
# ----------------------------------------
# Running Exp-126 of 486 (25.9%)
# Results for Exp-126: Accuracy=72.83%, Recall=73.33%, F1=71.10%
# ----------------------------------------
# Running Exp-127 of 486 (26.1%)
# Results for Exp-127: Accuracy=79.02%, Recall=78.57%, F1=78.79%
# ----------------------------------------
# Running Exp-128 of 486 (26.3%)
# Results for Exp-128: Accuracy=80.47%, Recall=80.54%, F1=80.40%
# ----------------------------------------
# Running Exp-129 of 486 (26.5%)
# Results for Exp-129: Accuracy=81.83%, Recall=81.81%, F1=81.88%
# ----------------------------------------
# Running Exp-130 of 486 (26.7%)
# Results for Exp-130: Accuracy=83.60%, Recall=83.57%, F1=83.47%
# ----------------------------------------
# Running Exp-131 of 486 (27.0%)
# Results for Exp-131: Accuracy=84.57%, Recall=84.38%, F1=84.38%
# ----------------------------------------
# Running Exp-132 of 486 (27.2%)
# Results for Exp-132: Accuracy=84.57%, Recall=84.62%, F1=84.50%
# ----------------------------------------
# Running Exp-133 of 486 (27.4%)
# Results for Exp-133: Accuracy=81.75%, Recall=81.47%, F1=81.51%
# ----------------------------------------
# Running Exp-134 of 486 (27.6%)
# Results for Exp-134: Accuracy=81.27%, Recall=81.01%, F1=81.19%
# ----------------------------------------
# Running Exp-135 of 486 (27.8%)
# Results for Exp-135: Accuracy=79.90%, Recall=79.62%, F1=79.74%
# ----------------------------------------
# Running Exp-136 of 486 (28.0%)
# Results for Exp-136: Accuracy=82.80%, Recall=82.71%, F1=82.70%
# ----------------------------------------
# Running Exp-137 of 486 (28.2%)
# Results for Exp-137: Accuracy=83.28%, Recall=83.46%, F1=83.18%
# ----------------------------------------
# Running Exp-138 of 486 (28.4%)
# Results for Exp-138: Accuracy=82.72%, Recall=82.77%, F1=82.64%
# ----------------------------------------
# Running Exp-139 of 486 (28.6%)
# Results for Exp-139: Accuracy=70.90%, Recall=70.69%, F1=69.09%
# ----------------------------------------
# Running Exp-140 of 486 (28.8%)
# Results for Exp-140: Accuracy=74.12%, Recall=74.22%, F1=72.63%
# ----------------------------------------
# Running Exp-141 of 486 (29.0%)
# Results for Exp-141: Accuracy=73.55%, Recall=73.66%, F1=71.86%
# ----------------------------------------
# Running Exp-142 of 486 (29.2%)
# Results for Exp-142: Accuracy=77.25%, Recall=77.35%, F1=76.43%
# ----------------------------------------
# Running Exp-143 of 486 (29.4%)
# Results for Exp-143: Accuracy=74.84%, Recall=75.22%, F1=73.61%
# ----------------------------------------
# Running Exp-144 of 486 (29.6%)
# Results for Exp-144: Accuracy=75.48%, Recall=75.58%, F1=74.19%
# ----------------------------------------
# Running Exp-145 of 486 (29.8%)
# Results for Exp-145: Accuracy=82.15%, Recall=81.95%, F1=82.08%
# ----------------------------------------
# Running Exp-146 of 486 (30.0%)
# Results for Exp-146: Accuracy=83.52%, Recall=83.40%, F1=83.49%
# ----------------------------------------
# Running Exp-147 of 486 (30.2%)
# Results for Exp-147: Accuracy=81.43%, Recall=81.41%, F1=81.36%
# ----------------------------------------
# Running Exp-148 of 486 (30.5%)
# Results for Exp-148: Accuracy=85.21%, Recall=85.10%, F1=85.17%
# ----------------------------------------
# Running Exp-149 of 486 (30.7%)
# Results for Exp-149: Accuracy=82.88%, Recall=82.90%, F1=82.75%
# ----------------------------------------
# Running Exp-150 of 486 (30.9%)
# Results for Exp-150: Accuracy=86.25%, Recall=86.27%, F1=86.17%
# ----------------------------------------
# Running Exp-151 of 486 (31.1%)
# Results for Exp-151: Accuracy=79.90%, Recall=79.96%, F1=79.74%
# ----------------------------------------
# Running Exp-152 of 486 (31.3%)
# Results for Exp-152: Accuracy=79.98%, Recall=79.71%, F1=79.73%
# ----------------------------------------
# Running Exp-153 of 486 (31.5%)
# Results for Exp-153: Accuracy=81.35%, Recall=81.43%, F1=81.19%
# ----------------------------------------
# Running Exp-154 of 486 (31.7%)
# Results for Exp-154: Accuracy=82.23%, Recall=82.23%, F1=82.10%
# ----------------------------------------
# Running Exp-155 of 486 (31.9%)
# Results for Exp-155: Accuracy=84.00%, Recall=84.16%, F1=84.02%
# ----------------------------------------
# Running Exp-156 of 486 (32.1%)
# Results for Exp-156: Accuracy=82.96%, Recall=82.92%, F1=82.89%
# ----------------------------------------
# Running Exp-157 of 486 (32.3%)
# Results for Exp-157: Accuracy=76.21%, Recall=76.13%, F1=75.47%
# ----------------------------------------
# Running Exp-158 of 486 (32.5%)
# Results for Exp-158: Accuracy=75.32%, Recall=75.29%, F1=74.50%
# ----------------------------------------
# Running Exp-159 of 486 (32.7%)
# Results for Exp-159: Accuracy=73.95%, Recall=73.63%, F1=73.32%
# ----------------------------------------
# Running Exp-160 of 486 (32.9%)
# Results for Exp-160: Accuracy=80.39%, Recall=80.39%, F1=80.28%
# ----------------------------------------
# Running Exp-161 of 486 (33.1%)
# Results for Exp-161: Accuracy=80.06%, Recall=80.12%, F1=79.72%
# ----------------------------------------
# Running Exp-162 of 486 (33.3%)
# Results for Exp-162: Accuracy=80.55%, Recall=80.69%, F1=80.35%
# ----------------------------------------
# Running Exp-163 of 486 (33.5%)
# Results for Exp-163: Accuracy=84.08%, Recall=84.03%, F1=83.92%
# ----------------------------------------
# Running Exp-164 of 486 (33.7%)
# Results for Exp-164: Accuracy=83.04%, Recall=82.76%, F1=82.86%
# ----------------------------------------
# Running Exp-165 of 486 (34.0%)
# Results for Exp-165: Accuracy=84.16%, Recall=84.01%, F1=84.09%
# ----------------------------------------
# Running Exp-166 of 486 (34.2%)
# Results for Exp-166: Accuracy=84.89%, Recall=84.65%, F1=84.77%
# ----------------------------------------
# Running Exp-167 of 486 (34.4%)
# Results for Exp-167: Accuracy=84.57%, Recall=84.49%, F1=84.47%
# ----------------------------------------
# Running Exp-168 of 486 (34.6%)
# Results for Exp-168: Accuracy=84.65%, Recall=84.50%, F1=84.55%
# ----------------------------------------
# Running Exp-169 of 486 (34.8%)
# Results for Exp-169: Accuracy=81.83%, Recall=81.37%, F1=81.69%
# ----------------------------------------
# Running Exp-170 of 486 (35.0%)
# Results for Exp-170: Accuracy=82.23%, Recall=82.18%, F1=82.10%
# ----------------------------------------
# Running Exp-171 of 486 (35.2%)
# Results for Exp-171: Accuracy=81.83%, Recall=81.58%, F1=81.59%
# ----------------------------------------
# Running Exp-172 of 486 (35.4%)
# Results for Exp-172: Accuracy=84.32%, Recall=84.13%, F1=84.22%
# ----------------------------------------
# Running Exp-173 of 486 (35.6%)
# Results for Exp-173: Accuracy=83.84%, Recall=83.79%, F1=83.80%
# ----------------------------------------
# Running Exp-174 of 486 (35.8%)
# Results for Exp-174: Accuracy=84.24%, Recall=84.19%, F1=84.17%
# ----------------------------------------
# Running Exp-175 of 486 (36.0%)
# Results for Exp-175: Accuracy=77.09%, Recall=76.96%, F1=76.43%
# ----------------------------------------
# Running Exp-176 of 486 (36.2%)
# Results for Exp-176: Accuracy=78.54%, Recall=78.60%, F1=78.04%
# ----------------------------------------
# Running Exp-177 of 486 (36.4%)
# Results for Exp-177: Accuracy=79.66%, Recall=79.47%, F1=79.37%
# ----------------------------------------
# Running Exp-178 of 486 (36.6%)
# Results for Exp-178: Accuracy=81.99%, Recall=82.09%, F1=81.83%
# ----------------------------------------
# Running Exp-179 of 486 (36.8%)
# Results for Exp-179: Accuracy=81.59%, Recall=81.63%, F1=81.32%
# ----------------------------------------
# Running Exp-180 of 486 (37.0%)
# Results for Exp-180: Accuracy=81.11%, Recall=81.19%, F1=80.95%
# ----------------------------------------
# Running Exp-181 of 486 (37.2%)
# Results for Exp-181: Accuracy=82.56%, Recall=82.37%, F1=82.26%
# ----------------------------------------
# Running Exp-182 of 486 (37.4%)
# Results for Exp-182: Accuracy=82.88%, Recall=82.70%, F1=82.69%
# ----------------------------------------
# Running Exp-183 of 486 (37.7%)
# Results for Exp-183: Accuracy=84.16%, Recall=84.03%, F1=84.08%
# ----------------------------------------
# Running Exp-184 of 486 (37.9%)
# Results for Exp-184: Accuracy=85.93%, Recall=85.82%, F1=85.84%
# ----------------------------------------
# Running Exp-185 of 486 (38.1%)
# Results for Exp-185: Accuracy=85.93%, Recall=85.89%, F1=85.87%
# ----------------------------------------
# Running Exp-186 of 486 (38.3%)
# Results for Exp-186: Accuracy=85.53%, Recall=85.50%, F1=85.50%
# ----------------------------------------
# Running Exp-187 of 486 (38.5%)
# Results for Exp-187: Accuracy=83.60%, Recall=83.29%, F1=83.46%
# ----------------------------------------
# Running Exp-188 of 486 (38.7%)
# Results for Exp-188: Accuracy=83.68%, Recall=83.32%, F1=83.51%
# ----------------------------------------
# Running Exp-189 of 486 (38.9%)
# Results for Exp-189: Accuracy=81.11%, Recall=80.67%, F1=80.93%
# ----------------------------------------
# Running Exp-190 of 486 (39.1%)
# Results for Exp-190: Accuracy=84.57%, Recall=84.19%, F1=84.42%
# ----------------------------------------
# Running Exp-191 of 486 (39.3%)
# Results for Exp-191: Accuracy=84.65%, Recall=84.48%, F1=84.55%
# ----------------------------------------
# Running Exp-192 of 486 (39.5%)
# Results for Exp-192: Accuracy=83.52%, Recall=83.34%, F1=83.36%
# ----------------------------------------
# Running Exp-193 of 486 (39.7%)
# Results for Exp-193: Accuracy=79.34%, Recall=78.81%, F1=79.19%
# ----------------------------------------
# Running Exp-194 of 486 (39.9%)
# Results for Exp-194: Accuracy=82.64%, Recall=82.55%, F1=82.41%
# ----------------------------------------
# Running Exp-195 of 486 (40.1%)
# Results for Exp-195: Accuracy=81.91%, Recall=81.69%, F1=81.75%
# ----------------------------------------
# Running Exp-196 of 486 (40.3%)
# Results for Exp-196: Accuracy=82.96%, Recall=82.98%, F1=82.77%
# ----------------------------------------
# Running Exp-197 of 486 (40.5%)
# Results for Exp-197: Accuracy=83.52%, Recall=83.46%, F1=83.38%
# ----------------------------------------
# Running Exp-198 of 486 (40.7%)
# Results for Exp-198: Accuracy=83.52%, Recall=83.41%, F1=83.47%
# ----------------------------------------
# Running Exp-199 of 486 (40.9%)
# Results for Exp-199: Accuracy=83.12%, Recall=82.99%, F1=83.03%
# ----------------------------------------
# Running Exp-200 of 486 (41.2%)
# Results for Exp-200: Accuracy=84.00%, Recall=83.64%, F1=83.89%
# ----------------------------------------
# Running Exp-201 of 486 (41.4%)
# Results for Exp-201: Accuracy=82.88%, Recall=82.62%, F1=82.77%
# ----------------------------------------
# Running Exp-202 of 486 (41.6%)
# Results for Exp-202: Accuracy=86.33%, Recall=86.00%, F1=86.16%
# ----------------------------------------
# Running Exp-203 of 486 (41.8%)
# Results for Exp-203: Accuracy=85.69%, Recall=85.51%, F1=85.66%
# ----------------------------------------
# Running Exp-204 of 486 (42.0%)
# Results for Exp-204: Accuracy=85.85%, Recall=85.83%, F1=85.73%
# ----------------------------------------
# Running Exp-205 of 486 (42.2%)
# Results for Exp-205: Accuracy=82.32%, Recall=82.03%, F1=82.23%
# ----------------------------------------
# Running Exp-206 of 486 (42.4%)
# Results for Exp-206: Accuracy=83.04%, Recall=83.20%, F1=82.95%
# ----------------------------------------
# Running Exp-207 of 486 (42.6%)
# Results for Exp-207: Accuracy=82.72%, Recall=82.42%, F1=82.58%
# ----------------------------------------
# Running Exp-208 of 486 (42.8%)
# Results for Exp-208: Accuracy=84.65%, Recall=84.77%, F1=84.57%
# ----------------------------------------
# Running Exp-209 of 486 (43.0%)
# Results for Exp-209: Accuracy=83.92%, Recall=83.73%, F1=83.86%
# ----------------------------------------
# Running Exp-210 of 486 (43.2%)
# Results for Exp-210: Accuracy=83.36%, Recall=83.27%, F1=83.17%
# ----------------------------------------
# Running Exp-211 of 486 (43.4%)
# Results for Exp-211: Accuracy=82.56%, Recall=82.51%, F1=82.36%
# ----------------------------------------
# Running Exp-212 of 486 (43.6%)
# Results for Exp-212: Accuracy=81.91%, Recall=81.82%, F1=81.82%
# ----------------------------------------
# Running Exp-213 of 486 (43.8%)
# Results for Exp-213: Accuracy=81.43%, Recall=81.52%, F1=81.09%
# ----------------------------------------
# Running Exp-214 of 486 (44.0%)
# Results for Exp-214: Accuracy=83.92%, Recall=83.87%, F1=83.88%
# ----------------------------------------
# Running Exp-215 of 486 (44.2%)
# Results for Exp-215: Accuracy=83.20%, Recall=83.10%, F1=83.17%
# ----------------------------------------
# Running Exp-216 of 486 (44.4%)
# Results for Exp-216: Accuracy=84.32%, Recall=84.13%, F1=84.25%
# ----------------------------------------
# Running Exp-217 of 486 (44.7%)
# Results for Exp-217: Accuracy=85.29%, Recall=85.43%, F1=85.17%
# ----------------------------------------
# Running Exp-218 of 486 (44.9%)
# Results for Exp-218: Accuracy=83.76%, Recall=83.57%, F1=83.75%
# ----------------------------------------
# Running Exp-219 of 486 (45.1%)
# Results for Exp-219: Accuracy=83.28%, Recall=82.91%, F1=83.18%
# ----------------------------------------
# Running Exp-220 of 486 (45.3%)
# Results for Exp-220: Accuracy=85.05%, Recall=85.10%, F1=85.10%
# ----------------------------------------
# Running Exp-221 of 486 (45.5%)
# Results for Exp-221: Accuracy=86.09%, Recall=86.04%, F1=85.98%
# ----------------------------------------
# Running Exp-222 of 486 (45.7%)
# Results for Exp-222: Accuracy=85.29%, Recall=85.34%, F1=85.26%
# ----------------------------------------
# Running Exp-223 of 486 (45.9%)
# Results for Exp-223: Accuracy=82.40%, Recall=82.27%, F1=82.27%
# ----------------------------------------
# Running Exp-224 of 486 (46.1%)
# Results for Exp-224: Accuracy=82.40%, Recall=82.33%, F1=82.34%
# ----------------------------------------
# Running Exp-225 of 486 (46.3%)
# Results for Exp-225: Accuracy=82.07%, Recall=82.10%, F1=81.89%
# ----------------------------------------
# Running Exp-226 of 486 (46.5%)
# Results for Exp-226: Accuracy=83.12%, Recall=83.15%, F1=83.03%
# ----------------------------------------
# Running Exp-227 of 486 (46.7%)
# Results for Exp-227: Accuracy=82.96%, Recall=82.94%, F1=82.89%
# ----------------------------------------
# Running Exp-228 of 486 (46.9%)
# Results for Exp-228: Accuracy=83.68%, Recall=83.75%, F1=83.60%
# ----------------------------------------
# Running Exp-229 of 486 (47.1%)
# Results for Exp-229: Accuracy=77.09%, Recall=77.32%, F1=75.97%
# ----------------------------------------
# Running Exp-230 of 486 (47.3%)
# Results for Exp-230: Accuracy=76.05%, Recall=76.20%, F1=74.88%
# ----------------------------------------
# Running Exp-231 of 486 (47.5%)
# Results for Exp-231: Accuracy=77.25%, Recall=77.07%, F1=76.72%
# ----------------------------------------
# Running Exp-232 of 486 (47.7%)
# Results for Exp-232: Accuracy=78.62%, Recall=78.62%, F1=78.20%
# ----------------------------------------
# Running Exp-233 of 486 (47.9%)
# Results for Exp-233: Accuracy=78.46%, Recall=78.54%, F1=77.85%
# ----------------------------------------
# Running Exp-234 of 486 (48.1%)
# Results for Exp-234: Accuracy=80.31%, Recall=80.43%, F1=80.18%
# ----------------------------------------
# Running Exp-235 of 486 (48.4%)
# Results for Exp-235: Accuracy=82.15%, Recall=81.86%, F1=82.08%
# ----------------------------------------
# Running Exp-236 of 486 (48.6%)
# Results for Exp-236: Accuracy=84.16%, Recall=83.87%, F1=84.05%
# ----------------------------------------
# Running Exp-237 of 486 (48.8%)
# Results for Exp-237: Accuracy=84.97%, Recall=84.94%, F1=85.03%
# ----------------------------------------
# Running Exp-238 of 486 (49.0%)
# Results for Exp-238: Accuracy=84.81%, Recall=84.43%, F1=84.73%
# ----------------------------------------
# Running Exp-239 of 486 (49.2%)
# Results for Exp-239: Accuracy=85.37%, Recall=84.97%, F1=85.20%
# ----------------------------------------
# Running Exp-240 of 486 (49.4%)
# Results for Exp-240: Accuracy=87.38%, Recall=87.39%, F1=87.24%
# ----------------------------------------
# Running Exp-241 of 486 (49.6%)
# Results for Exp-241: Accuracy=84.32%, Recall=84.22%, F1=84.33%
# ----------------------------------------
# Running Exp-242 of 486 (49.8%)
# Results for Exp-242: Accuracy=81.43%, Recall=81.35%, F1=81.08%
# ----------------------------------------
# Running Exp-243 of 486 (50.0%)
# Results for Exp-243: Accuracy=83.36%, Recall=83.45%, F1=83.18%
# ----------------------------------------
# Running Exp-244 of 486 (50.2%)
# Results for Exp-244: Accuracy=84.57%, Recall=84.44%, F1=84.52%
# ----------------------------------------
# Running Exp-245 of 486 (50.4%)
# Results for Exp-245: Accuracy=84.97%, Recall=85.03%, F1=84.87%
# ----------------------------------------
# Running Exp-246 of 486 (50.6%)
# Results for Exp-246: Accuracy=84.41%, Recall=84.37%, F1=84.30%
# ----------------------------------------
# Running Exp-247 of 486 (50.8%)
# Results for Exp-247: Accuracy=81.35%, Recall=81.30%, F1=81.23%
# ----------------------------------------
# Running Exp-248 of 486 (51.0%)
# Results for Exp-248: Accuracy=82.15%, Recall=82.13%, F1=82.02%
# ----------------------------------------
# Running Exp-249 of 486 (51.2%)
# Results for Exp-249: Accuracy=81.27%, Recall=81.33%, F1=81.19%
# ----------------------------------------
# Running Exp-250 of 486 (51.4%)
# Results for Exp-250: Accuracy=82.32%, Recall=82.30%, F1=82.15%
# ----------------------------------------
# Running Exp-251 of 486 (51.6%)
# Results for Exp-251: Accuracy=82.56%, Recall=82.29%, F1=82.58%
# ----------------------------------------
# Running Exp-252 of 486 (51.9%)
# Results for Exp-252: Accuracy=82.07%, Recall=81.89%, F1=81.92%
# ----------------------------------------
# Running Exp-253 of 486 (52.1%)
# Results for Exp-253: Accuracy=84.73%, Recall=84.57%, F1=84.49%
# ----------------------------------------
# Running Exp-254 of 486 (52.3%)
# Results for Exp-254: Accuracy=84.41%, Recall=84.27%, F1=84.35%
# ----------------------------------------
# Running Exp-255 of 486 (52.5%)
# Results for Exp-255: Accuracy=85.05%, Recall=85.19%, F1=84.95%
# ----------------------------------------
# Running Exp-256 of 486 (52.7%)
# Results for Exp-256: Accuracy=87.30%, Recall=87.27%, F1=87.22%
# ----------------------------------------
# Running Exp-257 of 486 (52.9%)
# Results for Exp-257: Accuracy=86.41%, Recall=86.43%, F1=86.26%
# ----------------------------------------
# Running Exp-258 of 486 (53.1%)
# Results for Exp-258: Accuracy=85.85%, Recall=85.97%, F1=85.67%
# ----------------------------------------
# Running Exp-259 of 486 (53.3%)
# Results for Exp-259: Accuracy=82.15%, Recall=81.69%, F1=82.04%
# ----------------------------------------
# Running Exp-260 of 486 (53.5%)
# Results for Exp-260: Accuracy=81.43%, Recall=81.08%, F1=81.13%
# ----------------------------------------
# Running Exp-261 of 486 (53.7%)
# Results for Exp-261: Accuracy=83.52%, Recall=83.63%, F1=83.50%
# ----------------------------------------
# Running Exp-262 of 486 (53.9%)
# Results for Exp-262: Accuracy=85.05%, Recall=84.94%, F1=85.00%
# ----------------------------------------
# Running Exp-263 of 486 (54.1%)
# Results for Exp-263: Accuracy=86.01%, Recall=85.76%, F1=85.95%
# ----------------------------------------
# Running Exp-264 of 486 (54.3%)
# Results for Exp-264: Accuracy=86.25%, Recall=86.29%, F1=86.22%
# ----------------------------------------
# Running Exp-265 of 486 (54.5%)
# Results for Exp-265: Accuracy=79.42%, Recall=79.30%, F1=79.31%
# ----------------------------------------
# Running Exp-266 of 486 (54.7%)
# Results for Exp-266: Accuracy=83.04%, Recall=83.04%, F1=83.04%
# ----------------------------------------
# Running Exp-267 of 486 (54.9%)
# Results for Exp-267: Accuracy=81.19%, Recall=80.70%, F1=81.14%
# ----------------------------------------
# Running Exp-268 of 486 (55.1%)
# Results for Exp-268: Accuracy=82.07%, Recall=82.15%, F1=82.09%
# ----------------------------------------
# Running Exp-269 of 486 (55.3%)
# Results for Exp-269: Accuracy=83.84%, Recall=83.68%, F1=83.78%
# ----------------------------------------
# Running Exp-270 of 486 (55.6%)
# Results for Exp-270: Accuracy=83.52%, Recall=83.45%, F1=83.49%
# ----------------------------------------
# Running Exp-271 of 486 (55.8%)
# Results for Exp-271: Accuracy=81.43%, Recall=81.65%, F1=81.08%
# ----------------------------------------
# Running Exp-272 of 486 (56.0%)
# Results for Exp-272: Accuracy=84.57%, Recall=84.46%, F1=84.42%
# ----------------------------------------
# Running Exp-273 of 486 (56.2%)
# Results for Exp-273: Accuracy=83.52%, Recall=83.49%, F1=83.64%
# ----------------------------------------
# Running Exp-274 of 486 (56.4%)
# Results for Exp-274: Accuracy=84.41%, Recall=84.37%, F1=84.28%
# ----------------------------------------
# Running Exp-275 of 486 (56.6%)
# Results for Exp-275: Accuracy=85.77%, Recall=86.04%, F1=85.65%
# ----------------------------------------
# Running Exp-276 of 486 (56.8%)
# Results for Exp-276: Accuracy=84.97%, Recall=84.92%, F1=84.86%
# ----------------------------------------
# Running Exp-277 of 486 (57.0%)
# Results for Exp-277: Accuracy=79.26%, Recall=79.09%, F1=78.98%
# ----------------------------------------
# Running Exp-278 of 486 (57.2%)
# Results for Exp-278: Accuracy=80.39%, Recall=80.51%, F1=80.08%
# ----------------------------------------
# Running Exp-279 of 486 (57.4%)
# Results for Exp-279: Accuracy=79.98%, Recall=80.01%, F1=79.61%
# ----------------------------------------
# Running Exp-280 of 486 (57.6%)
# Results for Exp-280: Accuracy=81.91%, Recall=81.82%, F1=81.70%
# ----------------------------------------
# Running Exp-281 of 486 (57.8%)
# Results for Exp-281: Accuracy=82.88%, Recall=82.89%, F1=82.81%
# ----------------------------------------
# Running Exp-282 of 486 (58.0%)
# Results for Exp-282: Accuracy=82.40%, Recall=82.67%, F1=82.12%
# ----------------------------------------
# Running Exp-283 of 486 (58.2%)
# Results for Exp-283: Accuracy=72.19%, Recall=72.02%, F1=70.93%
# ----------------------------------------
# Running Exp-284 of 486 (58.4%)
# Results for Exp-284: Accuracy=73.63%, Recall=73.71%, F1=72.69%
# ----------------------------------------
# Running Exp-285 of 486 (58.6%)
# Results for Exp-285: Accuracy=71.22%, Recall=70.98%, F1=70.90%
# ----------------------------------------
# Running Exp-286 of 486 (58.8%)
# Results for Exp-286: Accuracy=74.36%, Recall=74.75%, F1=73.15%
# ----------------------------------------
# Running Exp-287 of 486 (59.1%)
# Results for Exp-287: Accuracy=75.48%, Recall=75.43%, F1=74.29%
# ----------------------------------------
# Running Exp-288 of 486 (59.3%)
# Results for Exp-288: Accuracy=74.12%, Recall=74.51%, F1=73.38%
# ----------------------------------------
# Running Exp-289 of 486 (59.5%)
# Results for Exp-289: Accuracy=83.84%, Recall=83.53%, F1=83.72%
# ----------------------------------------
# Running Exp-290 of 486 (59.7%)
# Results for Exp-290: Accuracy=84.81%, Recall=84.75%, F1=84.71%
# ----------------------------------------
# Running Exp-291 of 486 (59.9%)
# Results for Exp-291: Accuracy=83.84%, Recall=83.65%, F1=83.70%
# ----------------------------------------
# Running Exp-292 of 486 (60.1%)
# Results for Exp-292: Accuracy=86.82%, Recall=86.67%, F1=86.63%
# ----------------------------------------
# Running Exp-293 of 486 (60.3%)
# Results for Exp-293: Accuracy=86.01%, Recall=85.85%, F1=85.91%
# ----------------------------------------
# Running Exp-294 of 486 (60.5%)
# Results for Exp-294: Accuracy=87.38%, Recall=87.18%, F1=87.22%
# ----------------------------------------
# Running Exp-295 of 486 (60.7%)
# Results for Exp-295: Accuracy=81.19%, Recall=81.14%, F1=81.01%
# ----------------------------------------
# Running Exp-296 of 486 (60.9%)
# Results for Exp-296: Accuracy=82.40%, Recall=82.58%, F1=82.24%
# ----------------------------------------
# Running Exp-297 of 486 (61.1%)
# Results for Exp-297: Accuracy=82.72%, Recall=82.77%, F1=82.43%
# ----------------------------------------
# Running Exp-298 of 486 (61.3%)
# Results for Exp-298: Accuracy=83.60%, Recall=83.50%, F1=83.46%
# ----------------------------------------
# Running Exp-299 of 486 (61.5%)
# Results for Exp-299: Accuracy=83.92%, Recall=83.87%, F1=83.79%
# ----------------------------------------
# Running Exp-300 of 486 (61.7%)
# Results for Exp-300: Accuracy=82.80%, Recall=82.76%, F1=82.72%
# ----------------------------------------
# Running Exp-301 of 486 (61.9%)
# Results for Exp-301: Accuracy=75.72%, Recall=75.76%, F1=74.49%
# ----------------------------------------
# Running Exp-302 of 486 (62.1%)
# Results for Exp-302: Accuracy=74.52%, Recall=74.60%, F1=73.16%
# ----------------------------------------
# Running Exp-303 of 486 (62.3%)
# Results for Exp-303: Accuracy=76.45%, Recall=76.62%, F1=75.62%
# ----------------------------------------
# Running Exp-304 of 486 (62.6%)
# Results for Exp-304: Accuracy=79.34%, Recall=79.54%, F1=78.94%
# ----------------------------------------
# Running Exp-305 of 486 (62.8%)
# Results for Exp-305: Accuracy=80.14%, Recall=80.30%, F1=79.75%
# ----------------------------------------
# Running Exp-306 of 486 (63.0%)
# Results for Exp-306: Accuracy=77.65%, Recall=78.03%, F1=76.59%
# ----------------------------------------
# Running Exp-307 of 486 (63.2%)
# Results for Exp-307: Accuracy=84.16%, Recall=83.95%, F1=84.08%
# ----------------------------------------
# Running Exp-308 of 486 (63.4%)
# Results for Exp-308: Accuracy=84.49%, Recall=84.46%, F1=84.43%
# ----------------------------------------
# Running Exp-309 of 486 (63.6%)
# Results for Exp-309: Accuracy=84.97%, Recall=84.64%, F1=84.92%
# ----------------------------------------
# Running Exp-310 of 486 (63.8%)
# Results for Exp-310: Accuracy=85.77%, Recall=85.73%, F1=85.74%
# ----------------------------------------
# Running Exp-311 of 486 (64.0%)
# Results for Exp-311: Accuracy=84.57%, Recall=84.20%, F1=84.46%
# ----------------------------------------
# Running Exp-312 of 486 (64.2%)
# Results for Exp-312: Accuracy=86.33%, Recall=86.28%, F1=86.14%
# ----------------------------------------
# Running Exp-313 of 486 (64.4%)
# Results for Exp-313: Accuracy=83.20%, Recall=83.06%, F1=83.26%
# ----------------------------------------
# Running Exp-314 of 486 (64.6%)
# Results for Exp-314: Accuracy=82.40%, Recall=82.12%, F1=82.29%
# ----------------------------------------
# Running Exp-315 of 486 (64.8%)
# Results for Exp-315: Accuracy=80.06%, Recall=79.67%, F1=79.85%
# ----------------------------------------
# Running Exp-316 of 486 (65.0%)
# Results for Exp-316: Accuracy=84.81%, Recall=84.97%, F1=84.67%
# ----------------------------------------
# Running Exp-317 of 486 (65.2%)
# Results for Exp-317: Accuracy=85.13%, Recall=84.92%, F1=84.96%
# ----------------------------------------
# Running Exp-318 of 486 (65.4%)
# Results for Exp-318: Accuracy=86.01%, Recall=85.97%, F1=85.94%
# ----------------------------------------
# Running Exp-319 of 486 (65.6%)
# Results for Exp-319: Accuracy=80.23%, Recall=79.99%, F1=80.09%
# ----------------------------------------
# Running Exp-320 of 486 (65.8%)
# Results for Exp-320: Accuracy=78.22%, Recall=78.03%, F1=78.11%
# ----------------------------------------
# Running Exp-321 of 486 (66.0%)
# Results for Exp-321: Accuracy=80.71%, Recall=80.66%, F1=80.75%
# ----------------------------------------
# Running Exp-322 of 486 (66.3%)
# Results for Exp-322: Accuracy=81.67%, Recall=81.78%, F1=81.65%
# ----------------------------------------
# Running Exp-323 of 486 (66.5%)
# Results for Exp-323: Accuracy=81.99%, Recall=81.81%, F1=81.95%
# ----------------------------------------
# Running Exp-324 of 486 (66.7%)
# Results for Exp-324: Accuracy=82.07%, Recall=82.08%, F1=81.95%
# ----------------------------------------
# Running Exp-325 of 486 (66.9%)
# Results for Exp-325: Accuracy=82.48%, Recall=82.39%, F1=82.27%
# ----------------------------------------
# Running Exp-326 of 486 (67.1%)
# Results for Exp-326: Accuracy=83.36%, Recall=83.23%, F1=83.16%
# ----------------------------------------
# Running Exp-327 of 486 (67.3%)
# Results for Exp-327: Accuracy=84.08%, Recall=83.87%, F1=83.94%
# ----------------------------------------
# Running Exp-328 of 486 (67.5%)
# Results for Exp-328: Accuracy=82.32%, Recall=82.17%, F1=82.14%
# ----------------------------------------
# Running Exp-329 of 486 (67.7%)
# Results for Exp-329: Accuracy=83.60%, Recall=83.30%, F1=83.50%
# ----------------------------------------
# Running Exp-330 of 486 (67.9%)
# Results for Exp-330: Accuracy=83.68%, Recall=83.50%, F1=83.49%
# ----------------------------------------
# Running Exp-331 of 486 (68.1%)
# Results for Exp-331: Accuracy=79.74%, Recall=79.45%, F1=79.35%
# ----------------------------------------
# Running Exp-332 of 486 (68.3%)
# Results for Exp-332: Accuracy=82.56%, Recall=82.49%, F1=82.35%
# ----------------------------------------
# Running Exp-333 of 486 (68.5%)
# Results for Exp-333: Accuracy=82.72%, Recall=82.54%, F1=82.60%
# ----------------------------------------
# Running Exp-334 of 486 (68.7%)
# Results for Exp-334: Accuracy=80.31%, Recall=80.32%, F1=79.88%
# ----------------------------------------
# Running Exp-335 of 486 (68.9%)
# Results for Exp-335: Accuracy=83.28%, Recall=83.32%, F1=83.09%
# ----------------------------------------
# Running Exp-336 of 486 (69.1%)
# Results for Exp-336: Accuracy=82.23%, Recall=82.11%, F1=82.06%
# ----------------------------------------
# Running Exp-337 of 486 (69.3%)
# Results for Exp-337: Accuracy=74.60%, Recall=74.27%, F1=73.69%
# ----------------------------------------
# Running Exp-338 of 486 (69.5%)
# Results for Exp-338: Accuracy=79.26%, Recall=79.07%, F1=78.77%
# ----------------------------------------
# Running Exp-339 of 486 (69.8%)
# Results for Exp-339: Accuracy=78.38%, Recall=78.39%, F1=77.74%
# ----------------------------------------
# Running Exp-340 of 486 (70.0%)
# Results for Exp-340: Accuracy=74.36%, Recall=74.43%, F1=72.98%
# ----------------------------------------
# Running Exp-341 of 486 (70.2%)
# Results for Exp-341: Accuracy=78.38%, Recall=78.48%, F1=77.69%
# ----------------------------------------
# Running Exp-342 of 486 (70.4%)
# Results for Exp-342: Accuracy=80.39%, Recall=80.54%, F1=79.94%
# ----------------------------------------
# Running Exp-343 of 486 (70.6%)
# Results for Exp-343: Accuracy=84.49%, Recall=84.43%, F1=84.38%
# ----------------------------------------
# Running Exp-344 of 486 (70.8%)
# Results for Exp-344: Accuracy=85.53%, Recall=85.43%, F1=85.51%
# ----------------------------------------
# Running Exp-345 of 486 (71.0%)
# Results for Exp-345: Accuracy=84.89%, Recall=84.60%, F1=84.76%
# ----------------------------------------
# Running Exp-346 of 486 (71.2%)
# Results for Exp-346: Accuracy=83.28%, Recall=83.16%, F1=83.09%
# ----------------------------------------
# Running Exp-347 of 486 (71.4%)
# Results for Exp-347: Accuracy=86.33%, Recall=86.23%, F1=86.22%
# ----------------------------------------
# Running Exp-348 of 486 (71.6%)
# Results for Exp-348: Accuracy=86.41%, Recall=86.36%, F1=86.36%
# ----------------------------------------
# Running Exp-349 of 486 (71.8%)
# Results for Exp-349: Accuracy=84.08%, Recall=83.88%, F1=83.94%
# ----------------------------------------
# Running Exp-350 of 486 (72.0%)
# Results for Exp-350: Accuracy=83.76%, Recall=83.57%, F1=83.62%
# ----------------------------------------
# Running Exp-351 of 486 (72.2%)
# Results for Exp-351: Accuracy=83.28%, Recall=83.06%, F1=83.05%
# ----------------------------------------
# Running Exp-352 of 486 (72.4%)
# Results for Exp-352: Accuracy=83.28%, Recall=83.34%, F1=83.06%
# ----------------------------------------
# Running Exp-353 of 486 (72.6%)
# Results for Exp-353: Accuracy=84.41%, Recall=84.29%, F1=84.32%
# ----------------------------------------
# Running Exp-354 of 486 (72.8%)
# Results for Exp-354: Accuracy=84.41%, Recall=84.19%, F1=84.28%
# ----------------------------------------
# Running Exp-355 of 486 (73.0%)
# Results for Exp-355: Accuracy=77.89%, Recall=77.91%, F1=77.12%
# ----------------------------------------
# Running Exp-356 of 486 (73.3%)
# Results for Exp-356: Accuracy=81.51%, Recall=81.44%, F1=81.15%
# ...
# Results for Exp-413: Accuracy=82.15%, Recall=82.28%, F1=81.89%
# ----------------------------------------
# Running Exp-414 of 486 (85.2%)
# Results for Exp-414: Accuracy=83.76%, Recall=83.70%, F1=83.59%
# ----------------------------------------
# Running Exp-415 of 486 (85.4%)
# Results for Exp-415: Accuracy=85.69%, Recall=85.52%, F1=85.55%
# ----------------------------------------
# Running Exp-416 of 486 (85.6%)
# Results for Exp-416: Accuracy=87.46%, Recall=87.25%, F1=87.29%
# ----------------------------------------
# Running Exp-417 of 486 (85.8%)
# Results for Exp-417: Accuracy=86.90%, Recall=86.73%, F1=86.83%
# ----------------------------------------
# Running Exp-418 of 486 (86.0%)
# Results for Exp-418: Accuracy=85.45%, Recall=85.32%, F1=85.33%
# ----------------------------------------
# Running Exp-419 of 486 (86.2%)
# Results for Exp-419: Accuracy=87.14%, Recall=86.89%, F1=87.02%
# ----------------------------------------
# Running Exp-420 of 486 (86.4%)
# Results for Exp-420: Accuracy=87.78%, Recall=87.52%, F1=87.60%
# ----------------------------------------
# Running Exp-421 of 486 (86.6%)
# Results for Exp-421: Accuracy=84.65%, Recall=84.43%, F1=84.47%
# ----------------------------------------
# Running Exp-422 of 486 (86.8%)
# Results for Exp-422: Accuracy=86.09%, Recall=85.83%, F1=85.96%
# ----------------------------------------
# Running Exp-423 of 486 (87.0%)
# Results for Exp-423: Accuracy=85.37%, Recall=85.28%, F1=85.29%
# ----------------------------------------
# Running Exp-424 of 486 (87.2%)
# Results for Exp-424: Accuracy=83.76%, Recall=83.66%, F1=83.67%
# ----------------------------------------
# Running Exp-425 of 486 (87.4%)
# Results for Exp-425: Accuracy=86.66%, Recall=86.44%, F1=86.53%
# ----------------------------------------
# Running Exp-426 of 486 (87.7%)
# Results for Exp-426: Accuracy=86.41%, Recall=86.28%, F1=86.32%
# ----------------------------------------
# Running Exp-427 of 486 (87.9%)
# Results for Exp-427: Accuracy=82.64%, Recall=82.61%, F1=82.46%
# ----------------------------------------
# Running Exp-428 of 486 (88.1%)
# Results for Exp-428: Accuracy=84.00%, Recall=83.91%, F1=83.91%
# ----------------------------------------
# Running Exp-429 of 486 (88.3%)
# Results for Exp-429: Accuracy=82.07%, Recall=81.71%, F1=81.90%
# ----------------------------------------
# Running Exp-430 of 486 (88.5%)
# Results for Exp-430: Accuracy=80.47%, Recall=80.08%, F1=80.24%
# ----------------------------------------
# Running Exp-431 of 486 (88.7%)
# Results for Exp-431: Accuracy=83.12%, Recall=82.97%, F1=83.05%
# ----------------------------------------
# Running Exp-432 of 486 (88.9%)
# Results for Exp-432: Accuracy=84.16%, Recall=84.24%, F1=84.12%
# ----------------------------------------
# Running Exp-433 of 486 (89.1%)
# Results for Exp-433: Accuracy=80.55%, Recall=80.33%, F1=80.23%
# ----------------------------------------
# Running Exp-434 of 486 (89.3%)
# Results for Exp-434: Accuracy=84.24%, Recall=84.26%, F1=84.02%
# ----------------------------------------
# Running Exp-435 of 486 (89.5%)
# Results for Exp-435: Accuracy=83.52%, Recall=83.17%, F1=83.42%
# ----------------------------------------
# Running Exp-436 of 486 (89.7%)
# Results for Exp-436: Accuracy=81.59%, Recall=81.61%, F1=81.17%
# ----------------------------------------
# Running Exp-437 of 486 (89.9%)
# Results for Exp-437: Accuracy=84.08%, Recall=84.21%, F1=84.03%
# ----------------------------------------
# Running Exp-438 of 486 (90.1%)
# Results for Exp-438: Accuracy=85.13%, Recall=84.84%, F1=85.03%
# ----------------------------------------
# Running Exp-439 of 486 (90.3%)
# Results for Exp-439: Accuracy=73.47%, Recall=73.48%, F1=71.58%
# ----------------------------------------
# Running Exp-440 of 486 (90.5%)
# Results for Exp-440: Accuracy=79.26%, Recall=79.18%, F1=78.76%
# ----------------------------------------
# Running Exp-441 of 486 (90.7%)
# Results for Exp-441: Accuracy=79.26%, Recall=79.44%, F1=78.35%
# ----------------------------------------
# Running Exp-442 of 486 (90.9%)
# Results for Exp-442: Accuracy=71.38%, Recall=71.61%, F1=68.43%
# ----------------------------------------
# Running Exp-443 of 486 (91.2%)
# Results for Exp-443: Accuracy=80.06%, Recall=80.45%, F1=79.29%
# ----------------------------------------
# Running Exp-444 of 486 (91.4%)
# Results for Exp-444: Accuracy=82.80%, Recall=82.83%, F1=82.61%
# ----------------------------------------
# Running Exp-445 of 486 (91.6%)
# Results for Exp-445: Accuracy=53.62%, Recall=52.99%, F1=43.96%
# ----------------------------------------
# Running Exp-446 of 486 (91.8%)
# Results for Exp-446: Accuracy=60.61%, Recall=59.86%, F1=54.28%
# ----------------------------------------
# Running Exp-447 of 486 (92.0%)
# Results for Exp-447: Accuracy=71.95%, Recall=71.69%, F1=70.69%
# ----------------------------------------
# Running Exp-448 of 486 (92.2%)
# Results for Exp-448: Accuracy=36.82%, Recall=33.15%, F1=23.24%
# ----------------------------------------
# Running Exp-449 of 486 (92.4%)
# Results for Exp-449: Accuracy=50.00%, Recall=49.70%, F1=38.57%
# ----------------------------------------
# Running Exp-450 of 486 (92.6%)
# Results for Exp-450: Accuracy=73.95%, Recall=73.82%, F1=72.75%
# ----------------------------------------
# Running Exp-451 of 486 (92.8%)
# Results for Exp-451: Accuracy=82.64%, Recall=82.50%, F1=82.51%
# ----------------------------------------
# Running Exp-452 of 486 (93.0%)
# Results for Exp-452: Accuracy=86.25%, Recall=86.27%, F1=86.21%
# ----------------------------------------
# Running Exp-453 of 486 (93.2%)
# Results for Exp-453: Accuracy=84.57%, Recall=84.65%, F1=84.43%
# ----------------------------------------
# Running Exp-454 of 486 (93.4%)
# Results for Exp-454: Accuracy=85.21%, Recall=85.20%, F1=85.15%
# ----------------------------------------
# Running Exp-455 of 486 (93.6%)
# Results for Exp-455: Accuracy=86.09%, Recall=86.07%, F1=86.00%
# ----------------------------------------
# Running Exp-456 of 486 (93.8%)
# Results for Exp-456: Accuracy=86.01%, Recall=85.80%, F1=85.86%
# ----------------------------------------
# Running Exp-457 of 486 (94.0%)
# Results for Exp-457: Accuracy=81.83%, Recall=82.00%, F1=81.49%
# ----------------------------------------
# Running Exp-458 of 486 (94.2%)
# Results for Exp-458: Accuracy=83.76%, Recall=83.57%, F1=83.66%
# ----------------------------------------
# Running Exp-459 of 486 (94.4%)
# Results for Exp-459: Accuracy=83.04%, Recall=82.88%, F1=82.89%
# ----------------------------------------
# Running Exp-460 of 486 (94.7%)
# Results for Exp-460: Accuracy=81.35%, Recall=81.29%, F1=81.05%
# ----------------------------------------
# Running Exp-461 of 486 (94.9%)
# Results for Exp-461: Accuracy=84.81%, Recall=84.92%, F1=84.70%
# ----------------------------------------
# Running Exp-462 of 486 (95.1%)
# Results for Exp-462: Accuracy=84.00%, Recall=84.07%, F1=83.72%
# ----------------------------------------
# Running Exp-463 of 486 (95.3%)
# Results for Exp-463: Accuracy=71.22%, Recall=71.27%, F1=68.81%
# ----------------------------------------
# Running Exp-464 of 486 (95.5%)
# Results for Exp-464: Accuracy=76.05%, Recall=76.20%, F1=74.60%
# ----------------------------------------
# Running Exp-465 of 486 (95.7%)
# Results for Exp-465: Accuracy=74.28%, Recall=74.43%, F1=72.57%
# ----------------------------------------
# Running Exp-466 of 486 (95.9%)
# Results for Exp-466: Accuracy=69.61%, Recall=69.90%, F1=65.80%
# ----------------------------------------
# Running Exp-467 of 486 (96.1%)
# Results for Exp-467: Accuracy=77.09%, Recall=77.45%, F1=75.47%
# ----------------------------------------
# Running Exp-468 of 486 (96.3%)
# Results for Exp-468: Accuracy=79.10%, Recall=79.27%, F1=78.28%
# ----------------------------------------
# Running Exp-469 of 486 (96.5%)
# Results for Exp-469: Accuracy=86.09%, Recall=85.89%, F1=85.96%
# ----------------------------------------
# Running Exp-470 of 486 (96.7%)
# Results for Exp-470: Accuracy=86.58%, Recall=86.31%, F1=86.47%
# ----------------------------------------
# Running Exp-471 of 486 (96.9%)
# Results for Exp-471: Accuracy=86.90%, Recall=86.79%, F1=86.85%
# ----------------------------------------
# Running Exp-472 of 486 (97.1%)
# Results for Exp-472: Accuracy=86.33%, Recall=86.27%, F1=86.27%
# ----------------------------------------
# Running Exp-473 of 486 (97.3%)
# Results for Exp-473: Accuracy=87.22%, Recall=87.02%, F1=87.09%
# ----------------------------------------
# Running Exp-474 of 486 (97.5%)
# Results for Exp-474: Accuracy=87.70%, Recall=87.39%, F1=87.61%
# ----------------------------------------
# Running Exp-475 of 486 (97.7%)
# Results for Exp-475: Accuracy=84.08%, Recall=84.14%, F1=83.84%
# ----------------------------------------
# Running Exp-476 of 486 (97.9%)
# Results for Exp-476: Accuracy=85.21%, Recall=85.19%, F1=85.08%
# ----------------------------------------
# Running Exp-477 of 486 (98.1%)
# Results for Exp-477: Accuracy=84.08%, Recall=83.93%, F1=83.90%
# ----------------------------------------
# Running Exp-478 of 486 (98.4%)
# Results for Exp-478: Accuracy=84.81%, Recall=84.97%, F1=84.77%
# ----------------------------------------
# Running Exp-479 of 486 (98.6%)
# Results for Exp-479: Accuracy=86.17%, Recall=86.11%, F1=86.08%
# ----------------------------------------
# Running Exp-480 of 486 (98.8%)
# Results for Exp-480: Accuracy=86.58%, Recall=86.36%, F1=86.46%
# ----------------------------------------
# Running Exp-481 of 486 (99.0%)
# Results for Exp-481: Accuracy=79.02%, Recall=78.99%, F1=78.32%
# ----------------------------------------
# Running Exp-482 of 486 (99.2%)
# Results for Exp-482: Accuracy=82.80%, Recall=82.70%, F1=82.57%
# ----------------------------------------
# Running Exp-483 of 486 (99.4%)
# Results for Exp-483: Accuracy=83.60%, Recall=83.58%, F1=83.44%
# ----------------------------------------
# Running Exp-484 of 486 (99.6%)
# Results for Exp-484: Accuracy=75.88%, Recall=76.01%, F1=74.28%
# ----------------------------------------
# Running Exp-485 of 486 (99.8%)
# Results for Exp-485: Accuracy=83.36%, Recall=83.45%, F1=83.15%
# ----------------------------------------
# Running Exp-486 of 486 (100.0%)
# Results for Exp-486: Accuracy=84.16%, Recall=84.06%, F1=84.09%
# ----------------------------------------
# All experiments completed. Results saved to ../experiments/tuning2/tuning_results.csv
#     Experiment  Number of Layers    Neurons per Layer  Learning Rate  \
# 0        Exp-1                 2            [128, 64]         0.0010
# 1        Exp-2                 2            [128, 64]         0.0010
# 2        Exp-3                 2            [128, 64]         0.0010
# 3        Exp-4                 2            [128, 64]         0.0010
# 4        Exp-5                 2            [128, 64]         0.0010
# ..         ...               ...                  ...            ...
# 481    Exp-482                 4  [512, 256, 128, 64]         0.0001
# 482    Exp-483                 4  [512, 256, 128, 64]         0.0001
# 483    Exp-484                 4  [512, 256, 128, 64]         0.0001
# 484    Exp-485                 4  [512, 256, 128, 64]         0.0001
# 485    Exp-486                 4  [512, 256, 128, 64]         0.0001
#
#      Dropout Rate  Batch Size  Epochs Optimizer  Accuracy  Recall  Value F1
# 0             0.3          16     100      Adam     81.43   81.29     81.38
# 1             0.3          16     200      Adam     81.75   81.41     81.59
# 2             0.3          16     300      Adam     81.75   81.58     81.56
# 3             0.3          32     100      Adam     84.57   84.54     84.42
# 4             0.3          32     200      Adam     84.32   84.11     84.18
# ..            ...         ...     ...       ...       ...     ...       ...
# 481           0.7          16     200      Adam     82.80   82.70     82.57
# 482           0.7          16     300      Adam     83.60   83.58     83.44
# 483           0.7          32     100      Adam     75.88   76.01     74.28
# 484           0.7          32     200      Adam     83.36   83.45     83.15
# 485           0.7          32     300      Adam     84.16   84.06     84.09
#
# [486 rows x 11 columns]
#
# Creating visualizations...
# Top 15 Configurations by Accuracy:
#     Experiment  Number of Layers    Neurons per Layer  Learning Rate  \
# 401    Exp-402                 3       [256, 128, 64]         0.0001
# 419    Exp-420                 3      [512, 256, 128]         0.0001
# 473    Exp-474                 4  [512, 256, 128, 64]         0.0001
# 415    Exp-416                 3      [512, 256, 128]         0.0001
# 293    Exp-294                 4   [256, 128, 64, 32]         0.0005
# 239    Exp-240                 3       [256, 128, 64]         0.0005
# 255    Exp-256                 3      [512, 256, 128]         0.0005
# 472    Exp-473                 4  [512, 256, 128, 64]         0.0001
# 418    Exp-419                 3      [512, 256, 128]         0.0001
# 364    Exp-365                 2           [512, 256]         0.0001
# 416    Exp-417                 3      [512, 256, 128]         0.0001
# 470    Exp-471                 4  [512, 256, 128, 64]         0.0001
# 291    Exp-292                 4   [256, 128, 64, 32]         0.0005
# 424    Exp-425                 3      [512, 256, 128]         0.0001
# 400    Exp-401                 3       [256, 128, 64]         0.0001
#
#      Dropout Rate  Batch Size  Epochs Optimizer  Accuracy  Recall  Value F1
# 401           0.3          32     300      Adam     87.86   87.79     87.74
# 419           0.3          32     300      Adam     87.78   87.52     87.60
# 473           0.3          32     300      Adam     87.70   87.39     87.61
# 415           0.3          16     200      Adam     87.46   87.25     87.29
# 293           0.3          32     300      Adam     87.38   87.18     87.22
# 239           0.3          32     300      Adam     87.38   87.39     87.24
# 255           0.3          32     100      Adam     87.30   87.27     87.22
# 472           0.3          32     200      Adam     87.22   87.02     87.09
# 418           0.3          32     200      Adam     87.14   86.89     87.02
# 364           0.3          32     200      Adam     86.98   87.00     86.84
# 416           0.3          16     300      Adam     86.90   86.73     86.83
# 470           0.3          16     300      Adam     86.90   86.79     86.85
# 291           0.3          32     100      Adam     86.82   86.67     86.63
# 424           0.5          32     200      Adam     86.66   86.44     86.53
# 400           0.3          32     200      Adam     86.66   86.67     86.46
# Visualizations saved to ../experiments/tuning2
#
# Top 5 configurations by accuracy:
#     Experiment  Number of Layers    Neurons per Layer  Learning Rate  \
# 401    Exp-402                 3       [256, 128, 64]         0.0001
# 419    Exp-420                 3      [512, 256, 128]         0.0001
# 473    Exp-474                 4  [512, 256, 128, 64]         0.0001
# 415    Exp-416                 3      [512, 256, 128]         0.0001
# 293    Exp-294                 4   [256, 128, 64, 32]         0.0005
#
#      Dropout Rate  Batch Size  Epochs Optimizer  Accuracy  Recall  Value F1  \
# 401           0.3          32     300      Adam     87.86   87.79     87.74
# 419           0.3          32     300      Adam     87.78   87.52     87.60
# 473           0.3          32     300      Adam     87.70   87.39     87.61
# 415           0.3          16     200      Adam     87.46   87.25     87.29
# 293           0.3          32     300      Adam     87.38   87.18     87.22
#
#         Network Architecture
# 401       3L: [256, 128, 64]
# 419      3L: [512, 256, 128]
# 473  4L: [512, 256, 128, 64]
# 415      3L: [512, 256, 128]
# 293   4L: [256, 128, 64, 32]
#
# Mean accuracy by parameter:
# Learning Rate: Learning Rate
# 0.0001    81.671111
# 0.0005    82.600926
# 0.0010    80.862222
# Name: Accuracy, dtype: float64
# Network Depth: Number of Layers
# 2    82.614815
# 3    82.375432
# 4    80.144012
# Name: Accuracy, dtype: float64
# Dropout Rate: Dropout Rate
# 0.3    84.362469
# 0.5    82.624321
# 0.7    78.147469
# Name: Accuracy, dtype: float64
# Epochs: Epochs
# 100    80.859938
# 200    81.979259
# 300    82.295062
# Name: Accuracy, dtype: float64
