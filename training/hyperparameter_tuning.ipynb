# %% [markdown]
# ## Sitting Posture Detection Training

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import f1_score, recall_score, accuracy_score
import os
import datetime
import itertools
import csv

# %% [markdown]
# ### Define Dataset class

# %%
class PostureDataset(Dataset):
    def __init__(self, data, scaler=None, label_encoder=None, from_csv=True):
        """
        Args:
        - data: CSV file path or DataFrame containing the dataset.
        - scaler: StandardScaler for feature normalization.
        - label_encoder: LabelEncoder for encoding the labels (not required if already encoded).
        - from_csv: Set to True if the input is a CSV path.
        """
        self.label_encoder = label_encoder

        # Load data
        if from_csv:
            data = pd.read_csv(data)
        
        # Ensure required columns are present
        if 'class' not in data.columns:
            raise ValueError("The input data must contain a 'class' column.")
        
        # Extract features and labels
        self.X = data.drop(columns=['class']).values  # Features
        self.y = data['class'].values  # Labels (already encoded)

        # Normalize features using StandardScaler
        if scaler:
            self.X = scaler.transform(self.X)
        else:
            self.scaler = StandardScaler()
            self.X = self.scaler.fit_transform(self.X)
        
        self.X = torch.tensor(self.X, dtype=torch.float32)
        self.y = torch.tensor(self.y, dtype=torch.long)  # Ensure labels are integers

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %% [markdown]
# ### Define ANN Model Architecture

# %%
class MLP(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden_layers, neurons_per_layer, dropout_rate):
        super(MLP, self).__init__()
        
        # Generate a decreasing neuron configuration based on the initial size
        # For example, if neurons_per_layer=512 and num_hidden_layers=3, 
        # we'll create [512, 256, 128]
        if not isinstance(neurons_per_layer, (list, tuple)):
            initial_neurons = neurons_per_layer
            neurons_list = []
            for i in range(num_hidden_layers):
                neurons_list.append(initial_neurons // (2**i))
        else:
            neurons_list = neurons_per_layer
            
        # Create the layers list
        layers = []
        
        # First hidden layer (from input_size to first layer size)
        layers.append(nn.Linear(input_size, neurons_list[0]))
        layers.append(nn.BatchNorm1d(neurons_list[0]))
        layers.append(nn.LeakyReLU(negative_slope=0.01))
        layers.append(nn.Dropout(dropout_rate))
        
        # Additional hidden layers with different sizes
        for i in range(1, num_hidden_layers):
            layers.append(nn.Linear(neurons_list[i-1], neurons_list[i]))
            layers.append(nn.BatchNorm1d(neurons_list[i]))
            layers.append(nn.LeakyReLU(negative_slope=0.01))
            layers.append(nn.Dropout(dropout_rate))
        
        # Output layer
        layers.append(nn.Linear(neurons_list[-1], num_classes))
        
        # Create the sequential model
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Define the Training & Evaluation Function

# %%
def evaluate_model(model, data_loader, device):
    """
    Evaluates the model and returns accuracy, recall, and F1 score.
    """
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    # Calculate metrics
    accuracy = accuracy_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')
    
    return accuracy * 100, recall * 100, f1 * 100

def train_model(model, train_loader, val_loader, criterion, optimizer, epochs, patience=15):
    """
    Train the model with early stopping based on validation loss.
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    # Initialize lists to store metrics
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []
    
    # Early stopping variables
    best_val_loss = float('inf')
    early_stop_counter = 0
    
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_loss = 0
        correct_train, total_train = 0, 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_acc = correct_train / total_train
        train_losses.append(train_loss / len(train_loader))
        train_accuracies.append(train_acc)
        
        # Validation Phase
        model.eval()
        val_loss, correct_val, total_val = 0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()
        
        val_acc = correct_val / total_val
        current_val_loss = val_loss / len(val_loader)
        val_losses.append(current_val_loss)
        val_accuracies.append(val_acc)
        
        # Early stopping check
        if current_val_loss < best_val_loss:
            best_val_loss = current_val_loss
            early_stop_counter = 0
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                break
    
    return train_losses, train_accuracies, val_losses, val_accuracies

# %% [markdown]
# ### Defining Dataset Loading Function

# %%
# Load and preprocess data
def load_and_prepare_data(csv_path):
    """
    Load the dataset, encode labels, and prepare for training.
    """
    df = pd.read_csv(csv_path)  
    
    print("Number of samples per class before train test split:")
    print(df['class'].value_counts())
    
    # Encode class labels to integers using LabelEncoder
    label_encoder = LabelEncoder()
    df['class'] = label_encoder.fit_transform(df['class'])
    
    # Split the data into training and test datasets
    RANDOM_SEED = 42
    torch.manual_seed(RANDOM_SEED)
    torch.cuda.manual_seed(RANDOM_SEED)
    
    train_data, test_data = train_test_split(df, test_size=0.3, random_state=RANDOM_SEED)
    
    # Standardize features
    scaler = StandardScaler()
    train_features = train_data.drop(columns=['class']).values
    scaler.fit(train_features)
    
    return train_data, test_data, scaler, label_encoder

# %% [markdown]
# ### Function to run single experiment

# %%
def run_experiment(hyperparams, train_data, test_data, scaler, label_encoder, exp_id, num_classes=4):
    """
    Run a single experiment with the given hyperparameters and return the results.
    """
    # Extract hyperparameters
    learning_rate = hyperparams['learning_rate']
    num_hidden_layers = hyperparams['num_hidden_layers']
    neurons_per_layer = hyperparams['neurons_per_layer']
    dropout_rate = hyperparams['dropout_rate']
    batch_size = hyperparams['batch_size']
    epochs = hyperparams['epochs']
    
    # Create datasets and loaders
    train_dataset = PostureDataset(train_data, scaler=scaler, label_encoder=label_encoder, from_csv=False)
    test_dataset = PostureDataset(test_data, scaler=scaler, label_encoder=label_encoder, from_csv=False)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    # Model initialization
    input_size = train_data.drop(columns=['class']).shape[1]
    
    model = MLP(input_size, num_classes, num_hidden_layers, neurons_per_layer, dropout_rate)
    
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.005)
    
    # Train the model
    train_losses, train_accuracies, val_losses, val_accuracies = train_model(
        model, train_loader, test_loader, criterion, optimizer, epochs
    )
    
    # Evaluate the model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    accuracy, recall, f1 = evaluate_model(model, test_loader, device)
    
    # Store metrics
    metrics = {
        'accuracy': accuracy,
        'recall': recall,
        'f1_score': f1,
        'best_val_loss': min(val_losses),
        'best_val_accuracy': max(val_accuracies)
    }
    
    return metrics

# %% [markdown]
# ### Defining the Grid Search Function

# %%
def hyperparameter_grid_search(grid, train_data, test_data, scaler, label_encoder, csv_file='../experiments/tuning/tuning_results_2.csv'):
    """
    Perform a grid search over the hyperparameter space and save only the CSV results.
    """
    # Create directory for the CSV if needed
    os.makedirs(os.path.dirname(os.path.abspath(csv_file)) if os.path.dirname(csv_file) else '.', exist_ok=True)
    
    # Define CSV headers
    headers = [
        'Experiment', 'Number of Layers', 'Neurons per Layer', 'Learning Rate',
        'Dropout Rate', 'Batch Size', 'Epochs', 'Optimizer', 'Accuracy', 'Recall', 'Value F1'
    ]
    
    # Write the header row with explicit UTF-8 encoding
    with open(csv_file, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(headers)
    
    # Generate all combinations of hyperparameters
    keys = grid.keys()
    values = grid.values()
    combinations = list(itertools.product(*values))
    total_experiments = len(combinations)
    
    # Run each experiment
    results = []
    
    print(f"Starting grid search with {total_experiments} experiments...")
    
    for i, combo in enumerate(combinations):
        # Create hyperparameter dictionary
        hyperparams = dict(zip(keys, combo))
        
        # Create experiment ID
        exp_id = f"Exp-{i+1}"
        
        # Generate the decreasing neuron configuration
        initial_neurons = hyperparams['neurons_per_layer']

        # Add this check to handle if initial_neurons is already a list
        if isinstance(initial_neurons, (list, tuple)):
            neuron_config = initial_neurons  # Use it directly
        else:
            # Otherwise, generate decreasing neuron pattern
            num_layers = hyperparams['num_hidden_layers']
            neuron_config = []
            for j in range(num_layers):
                neuron_config.append(initial_neurons // (2**j))
        
        # Store the complete neuron configuration
        hyperparams['neuron_config'] = neuron_config
        
        # Print progress info
        print(f"Running {exp_id} of {total_experiments} ({(i+1)/total_experiments*100:.1f}%)")
        
        # Run the experiment
        metrics = run_experiment(
            hyperparams, train_data, test_data, 
            scaler, label_encoder, exp_id
        )
        
        # Prepare row for CSV
        row = [
            exp_id,
            hyperparams['num_hidden_layers'],
            str(neuron_config),  # Store as string representation of list
            hyperparams['learning_rate'],
            hyperparams['dropout_rate'],
            hyperparams['batch_size'],
            hyperparams['epochs'],
            'Adam',  # Fixed to Adam
            f"{metrics['accuracy']:.2f}",
            f"{metrics['recall']:.2f}",
            f"{metrics['f1_score']:.2f}"
        ]
        
        # Write the results to the CSV file with explicit UTF-8 encoding
        with open(csv_file, 'a', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(row)
        
        # Store results
        results.append({
            'hyperparams': hyperparams,
            'metrics': metrics
        })
        
        # Print results for this experiment
        print(f"Results for {exp_id}: Accuracy={metrics['accuracy']:.2f}%, Recall={metrics['recall']:.2f}%, F1={metrics['f1_score']:.2f}%")
        print("-" * 40)
    
    return results, csv_file

# %% [markdown]
# ### Function to visualise hyperparameter results

# %%
def visualize_hyperparameter_results(csv_file, output_dir='../experiments/tuning'):
    """
    Visualize the hyperparameter tuning results in a more compact way.
    Creates heatmaps and bar charts to display the results.
    """
    import matplotlib.pyplot as plt
    import seaborn as sns
    import pandas as pd
    import os
    import numpy as np
    
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Load results
    results = pd.read_csv(csv_file)
    
    # Convert string metrics to numeric
    for col in ['Accuracy', 'Recall', 'Value F1']:
        results[col] = pd.to_numeric(results[col])
    
    # 1. Top Performers Table - show only top 15 results sorted by accuracy
    top_performers = results.sort_values('Accuracy', ascending=False).head(15)
    print("Top 15 Configurations by Accuracy:")
    print(top_performers)
    
    # Save top performers to CSV
    top_performers.to_csv(os.path.join(output_dir, 'top_performers.csv'), index=False)
    
    # ---------- VISUALIZATIONS ----------
    
    # 2. Create plots in a 2x3 grid
    plt.figure(figsize=(20, 15))
    
    # 2.1 Learning Rate vs Dropout Rate (with accuracy as color)
    plt.subplot(2, 3, 1)
    pivot = results.pivot_table(
        values='Accuracy', 
        index='Learning Rate',
        columns='Dropout Rate', 
        aggfunc='mean'
    )
    sns.heatmap(pivot, annot=True, cmap='YlGnBu', fmt='.1f')
    plt.title('Mean Accuracy by Learning Rate and Dropout Rate')
    
    # 2.2 Learning Rate vs Number of Layers
    plt.subplot(2, 3, 2)
    pivot = results.pivot_table(
        values='Accuracy', 
        index='Learning Rate',
        columns='Number of Layers', 
        aggfunc='mean'
    )
    sns.heatmap(pivot, annot=True, cmap='YlGnBu', fmt='.1f')
    plt.title('Mean Accuracy by Learning Rate and Network Depth')
    
    # 2.3 Epochs vs Number of Layers
    plt.subplot(2, 3, 3)
    pivot = results.pivot_table(
        values='Accuracy', 
        index='Epochs',
        columns='Number of Layers', 
        aggfunc='mean'
    )
    sns.heatmap(pivot, annot=True, cmap='YlGnBu', fmt='.1f')
    plt.title('Mean Accuracy by Epochs and Network Depth')
    
    # 2.4 Bar chart of metrics by Number of Layers
    plt.subplot(2, 3, 4)
    metrics_by_layers = results.groupby('Number of Layers')[['Accuracy', 'Recall', 'Value F1']].mean().reset_index()
    metrics_by_layers.plot(x='Number of Layers', kind='bar', ax=plt.gca())
    plt.title('Performance Metrics by Network Depth')
    plt.ylabel('Score')
    plt.xticks(rotation=0)
    
    # 2.5 Bar chart of metrics by Learning Rate
    plt.subplot(2, 3, 5)
    metrics_by_lr = results.groupby('Learning Rate')[['Accuracy', 'Recall', 'Value F1']].mean().reset_index()
    metrics_by_lr.plot(x='Learning Rate', kind='bar', ax=plt.gca())
    plt.title('Performance Metrics by Learning Rate')
    plt.ylabel('Score')
    plt.xticks(rotation=0)
    
    # 2.6 Bar chart of metrics by Epochs
    plt.subplot(2, 3, 6)
    metrics_by_epochs = results.groupby('Epochs')[['Accuracy', 'Recall', 'Value F1']].mean().reset_index()
    metrics_by_epochs.plot(x='Epochs', kind='bar', ax=plt.gca())
    plt.title('Performance Metrics by Epochs')
    plt.ylabel('Score')
    plt.xticks(rotation=0)
    
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'hyperparameter_visualization_grid.png'))
    plt.close()
    
    # 3. Network architectures comparison
    plt.figure(figsize=(14, 8))
    
    # Create a more readable representation of network architecture
    results['Network Architecture'] = results.apply(
        lambda row: f"{row['Number of Layers']}L: {row['Neurons per Layer']}", axis=1
    )
    
    # Get top 2 performing architectures for each depth
    top_archs = []
    for depth in results['Number of Layers'].unique():
        filtered = results[results['Number of Layers'] == depth]
        best_archs = filtered.groupby('Neurons per Layer')['Accuracy'].mean().nlargest(1).index.tolist()
        for arch in best_archs:
            top_archs.append((depth, arch))
    
    # Filter results to only include top architectures
    filtered_results = results[results.apply(
        lambda row: (row['Number of Layers'], row['Neurons per Layer']) in top_archs, axis=1
    )]
    
    # Get mean metrics for each architecture
    arch_metrics = filtered_results.groupby('Network Architecture')[['Accuracy', 'Recall', 'Value F1']].mean()
    
    # Sort by accuracy
    arch_metrics = arch_metrics.sort_values('Accuracy', ascending=False)
    
    # Plot
    arch_metrics.plot(kind='barh', figsize=(10, 8))
    plt.title('Performance Comparison of Top Network Architectures')
    plt.xlabel('Score')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'network_architecture_comparison.png'))
    plt.close()
    
    # 4. Learning curves - Accuracy vs Epochs for different configurations
    plt.figure(figsize=(14, 8))
    
    # Group by epochs and compute mean, min, max
    epoch_stats = results.groupby('Epochs')[['Accuracy', 'Recall', 'Value F1']].agg(['mean', 'min', 'max'])
    
    # Plot accuracy vs epochs with error bars
    x = np.array(epoch_stats.index)
    y = epoch_stats['Accuracy']['mean'].values
    min_vals = epoch_stats['Accuracy']['min'].values
    max_vals = epoch_stats['Accuracy']['max'].values
    
    plt.errorbar(x, y, yerr=[y-min_vals, max_vals-y], fmt='-o', capsize=5, label='Accuracy')
    
    # Plot recall and F1 as well
    plt.plot(x, epoch_stats['Recall']['mean'].values, 's-', label='Recall')
    plt.plot(x, epoch_stats['Value F1']['mean'].values, '^-', label='F1 Score')
    
    plt.xlabel('Epochs')
    plt.ylabel('Score')
    plt.title('Performance Metrics vs Training Epochs')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.savefig(os.path.join(output_dir, 'epoch_performance.png'))
    plt.close()
    
    # 5. Parameter importance analysis
    plt.figure(figsize=(12, 8))
    
    # Compute variance in accuracy for each parameter
    param_variance = {}
    for param in ['Learning Rate', 'Number of Layers', 'Dropout Rate', 'Epochs']:
        param_variance[param] = results.groupby(param)['Accuracy'].mean().var()
    
    # Convert to DataFrame and sort
    param_var_df = pd.DataFrame.from_dict(param_variance, orient='index', columns=['Variance'])
    param_var_df = param_var_df.sort_values('Variance', ascending=False)
    
    # Plot
    param_var_df.plot(kind='bar', figsize=(10, 6))
    plt.title('Hyperparameter Importance (Higher Variance = More Impact)')
    plt.ylabel('Variance in Accuracy')
    plt.xlabel('Hyperparameter')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'parameter_importance.png'))
    plt.close()
    
    # 6. Create a table-like visualization summarizing the best configurations
    plt.figure(figsize=(12, 8))
    
    # Get top configurations for each metric
    top_configs = {
        'Accuracy': results.sort_values('Accuracy', ascending=False).iloc[0],
        'Recall': results.sort_values('Recall', ascending=False).iloc[0],
        'F1 Score': results.sort_values('Value F1', ascending=False).iloc[0]
    }
    
    # Create table data
    table_data = [
        [metric, 
         f"{config['Learning Rate']}", 
         f"{config['Number of Layers']}", 
         f"{config['Neurons per Layer']}", 
         f"{config['Dropout Rate']}", 
         f"{config['Epochs']}", 
         f"{config['Accuracy']:.2f}", 
         f"{config['Recall']:.2f}", 
         f"{config['Value F1']:.2f}"]
        for metric, config in top_configs.items()
    ]
    
    # Create table
    ax = plt.gca()
    ax.axis('off')
    table = ax.table(
        cellText=table_data,
        colLabels=['Optimized For', 'LR', 'Layers', 'Neurons', 'Dropout', 'Epochs', 'Accuracy', 'Recall', 'F1'],
        loc='center',
        cellLoc='center'
    )
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1.2, 1.5)
    
    plt.title('Best Configurations by Metric', y=0.8)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'best_configs_table.png'))
    plt.close()
    
    print(f"Visualizations saved to {output_dir}")
    
    # Return detailed statistics for further analysis
    return {
        'top_by_accuracy': results.sort_values('Accuracy', ascending=False).head(5),
        'top_by_f1': results.sort_values('Value F1', ascending=False).head(5),
        'top_by_recall': results.sort_values('Recall', ascending=False).head(5),
        'mean_by_lr': results.groupby('Learning Rate')['Accuracy'].mean(),
        'mean_by_layers': results.groupby('Number of Layers')['Accuracy'].mean(),
        'mean_by_dropout': results.groupby('Dropout Rate')['Accuracy'].mean(),
        'mean_by_epochs': results.groupby('Epochs')['Accuracy'].mean(),
    }

# %% [markdown]
# ### Main Execution Function

# %%
# Main execution function
def main():
    # Define the hyperparameter grid
    hyperparameter_grid = {
        'learning_rate': [0.001, 0.0005, 0.0001],
        'num_hidden_layers': [2, 3, 4],
        'neurons_per_layer': [128, 256, 512],
        'dropout_rate': [0.3, 0.4, 0.5, 0.7],
        'batch_size': [16, 32],
        'epochs': [100, 200, 300]
    }

    # Load and prepare data
    csv_path = "../../datasets/vectors/augmented_xy_filtered_keypoints_vectors_mediapipe.csv"
    train_data, test_data, scaler, label_encoder = load_and_prepare_data(
        csv_path)

    # For the full grid, uncomment this line
    results, csv_file = hyperparameter_grid_search(
        hyperparameter_grid, train_data, test_data, scaler, label_encoder)

    print(f"All experiments completed. Results saved to {csv_file}")

    # Load the results as a DataFrame and display
    df_results = pd.read_csv(csv_file)
    print(df_results)
    
    # Visualize results
    print("\nCreating visualizations...")
    stats = visualize_hyperparameter_results(csv_file)
    
    print("\nTop 5 configurations by accuracy:")
    print(stats['top_by_accuracy'])
    
    print("\nMean accuracy by parameter:")
    print("Learning Rate:", stats['mean_by_lr'])
    print("Network Depth:", stats['mean_by_layers'])
    print("Dropout Rate:", stats['mean_by_dropout'])
    print("Epochs:", stats['mean_by_epochs'])


if __name__ == "__main__":
    main()
# Out:
# Number of samples per class before train test split:
# class
# crossed_legs    1091
# proper          1084
# slouching       1000
# reclining        970
# Name: count, dtype: int64
# Starting grid search with 648 experiments...
# Running Exp-1 of 648 (0.2%)
# Results for Exp-1: Accuracy=81.43%, Recall=81.29%, F1=81.38%
# ----------------------------------------
# Running Exp-2 of 648 (0.3%)
# Results for Exp-2: Accuracy=81.75%, Recall=81.41%, F1=81.59%
# ----------------------------------------
# Running Exp-3 of 648 (0.5%)
# Results for Exp-3: Accuracy=81.75%, Recall=81.58%, F1=81.56%
# ----------------------------------------
# Running Exp-4 of 648 (0.6%)
# Results for Exp-4: Accuracy=84.57%, Recall=84.54%, F1=84.42%
# ----------------------------------------
# Running Exp-5 of 648 (0.8%)
# Results for Exp-5: Accuracy=84.32%, Recall=84.11%, F1=84.18%
# ----------------------------------------
# Running Exp-6 of 648 (0.9%)
# Results for Exp-6: Accuracy=84.16%, Recall=84.02%, F1=84.02%
# ----------------------------------------
# Running Exp-7 of 648 (1.1%)
# Results for Exp-7: Accuracy=82.72%, Recall=82.49%, F1=82.57%
# ----------------------------------------
# Running Exp-8 of 648 (1.2%)
# Results for Exp-8: Accuracy=81.67%, Recall=81.33%, F1=81.60%
# ----------------------------------------
# Running Exp-9 of 648 (1.4%)
# Results for Exp-9: Accuracy=82.64%, Recall=82.54%, F1=82.65%
# ----------------------------------------
# Running Exp-10 of 648 (1.5%)
# Results for Exp-10: Accuracy=82.96%, Recall=82.68%, F1=82.81%
# ----------------------------------------
# Running Exp-11 of 648 (1.7%)
# Results for Exp-11: Accuracy=85.69%, Recall=85.63%, F1=85.55%
# ----------------------------------------
# Running Exp-12 of 648 (1.9%)
# Results for Exp-12: Accuracy=84.41%, Recall=84.37%, F1=84.34%
# ----------------------------------------
# Running Exp-13 of 648 (2.0%)
# Results for Exp-13: Accuracy=81.91%, Recall=81.97%, F1=81.71%
# ----------------------------------------
# Running Exp-14 of 648 (2.2%)
# Results for Exp-14: Accuracy=80.95%, Recall=80.75%, F1=80.80%
# ----------------------------------------
# Running Exp-15 of 648 (2.3%)
# Results for Exp-15: Accuracy=81.99%, Recall=81.64%, F1=81.89%
# ----------------------------------------
# Running Exp-16 of 648 (2.5%)
# Results for Exp-16: Accuracy=82.88%, Recall=82.78%, F1=82.83%
# ----------------------------------------
# Running Exp-17 of 648 (2.6%)
# Results for Exp-17: Accuracy=83.44%, Recall=83.54%, F1=83.44%
# ----------------------------------------
# Running Exp-18 of 648 (2.8%)
# Results for Exp-18: Accuracy=82.32%, Recall=82.23%, F1=82.18%
# ----------------------------------------
# Running Exp-19 of 648 (2.9%)
# Results for Exp-19: Accuracy=77.49%, Recall=77.43%, F1=76.97%
# ----------------------------------------
# Running Exp-20 of 648 (3.1%)
# Results for Exp-20: Accuracy=77.65%, Recall=77.74%, F1=77.20%
# ----------------------------------------
# Running Exp-21 of 648 (3.2%)
# Results for Exp-21: Accuracy=78.70%, Recall=78.75%, F1=78.24%
# ----------------------------------------
# Running Exp-22 of 648 (3.4%)
# Results for Exp-22: Accuracy=81.35%, Recall=81.43%, F1=81.25%
# ----------------------------------------
# Running Exp-23 of 648 (3.5%)
# Results for Exp-23: Accuracy=81.59%, Recall=81.44%, F1=81.46%
# ----------------------------------------
# Running Exp-24 of 648 (3.7%)
# Results for Exp-24: Accuracy=80.63%, Recall=80.68%, F1=80.31%
# ----------------------------------------
# Running Exp-25 of 648 (3.9%)
# Results for Exp-25: Accuracy=82.80%, Recall=82.64%, F1=82.54%
# ----------------------------------------
# Running Exp-26 of 648 (4.0%)
# Results for Exp-26: Accuracy=82.23%, Recall=81.70%, F1=82.09%
# ----------------------------------------
# Running Exp-27 of 648 (4.2%)
# Results for Exp-27: Accuracy=82.80%, Recall=82.66%, F1=82.67%
# ----------------------------------------
# Running Exp-28 of 648 (4.3%)
# Results for Exp-28: Accuracy=83.36%, Recall=83.23%, F1=83.21%
# ----------------------------------------
# Running Exp-29 of 648 (4.5%)
# Results for Exp-29: Accuracy=84.49%, Recall=84.37%, F1=84.28%
# ----------------------------------------
# Running Exp-30 of 648 (4.6%)
# Results for Exp-30: Accuracy=82.96%, Recall=82.78%, F1=82.77%
# ----------------------------------------
# Running Exp-31 of 648 (4.8%)
# Results for Exp-31: Accuracy=82.40%, Recall=82.34%, F1=82.28%
# ----------------------------------------
# Running Exp-32 of 648 (4.9%)
# Results for Exp-32: Accuracy=83.36%, Recall=83.19%, F1=83.27%
# ----------------------------------------
# Running Exp-33 of 648 (5.1%)
# Results for Exp-33: Accuracy=83.04%, Recall=82.97%, F1=82.74%
# ----------------------------------------
# Running Exp-34 of 648 (5.2%)
# Results for Exp-34: Accuracy=84.49%, Recall=84.31%, F1=84.37%
# ----------------------------------------
# Running Exp-35 of 648 (5.4%)
# Results for Exp-35: Accuracy=83.92%, Recall=83.82%, F1=83.82%
# ----------------------------------------
# Running Exp-36 of 648 (5.6%)
# Results for Exp-36: Accuracy=84.00%, Recall=83.88%, F1=83.97%
# ----------------------------------------
# Running Exp-37 of 648 (5.7%)
# Results for Exp-37: Accuracy=79.02%, Recall=78.60%, F1=78.68%
# ----------------------------------------
# Running Exp-38 of 648 (5.9%)
# Results for Exp-38: Accuracy=81.35%, Recall=81.20%, F1=81.32%
# ----------------------------------------
# Running Exp-39 of 648 (6.0%)
# Results for Exp-39: Accuracy=80.87%, Recall=80.63%, F1=80.72%
# ----------------------------------------
# Running Exp-40 of 648 (6.2%)
# Results for Exp-40: Accuracy=83.12%, Recall=83.14%, F1=82.94%
# ----------------------------------------
# Running Exp-41 of 648 (6.3%)
# Results for Exp-41: Accuracy=84.57%, Recall=84.27%, F1=84.51%
# ----------------------------------------
# Running Exp-42 of 648 (6.5%)
# Results for Exp-42: Accuracy=83.12%, Recall=83.31%, F1=83.00%
# ----------------------------------------
# Running Exp-43 of 648 (6.6%)
# Results for Exp-43: Accuracy=78.94%, Recall=78.88%, F1=78.57%
# ----------------------------------------
# Running Exp-44 of 648 (6.8%)
# Results for Exp-44: Accuracy=79.98%, Recall=80.14%, F1=79.56%
# ----------------------------------------
# Running Exp-45 of 648 (6.9%)
# Results for Exp-45: Accuracy=79.90%, Recall=79.71%, F1=79.59%
# ----------------------------------------
# Running Exp-46 of 648 (7.1%)
# Results for Exp-46: Accuracy=83.20%, Recall=83.16%, F1=83.05%
# ----------------------------------------
# Running Exp-47 of 648 (7.3%)
# Results for Exp-47: Accuracy=81.83%, Recall=81.72%, F1=81.80%
# ----------------------------------------
# Running Exp-48 of 648 (7.4%)
# Results for Exp-48: Accuracy=82.23%, Recall=82.14%, F1=82.13%
# ----------------------------------------
# Running Exp-49 of 648 (7.6%)
# Results for Exp-49: Accuracy=81.59%, Recall=81.44%, F1=81.46%
# ----------------------------------------
# Running Exp-50 of 648 (7.7%)
# Results for Exp-50: Accuracy=79.58%, Recall=79.67%, F1=79.25%
# ----------------------------------------
# Running Exp-51 of 648 (7.9%)
# Results for Exp-51: Accuracy=82.32%, Recall=82.04%, F1=82.19%
# ----------------------------------------
# Running Exp-52 of 648 (8.0%)
# Results for Exp-52: Accuracy=82.32%, Recall=82.30%, F1=81.98%
# ----------------------------------------
# Running Exp-53 of 648 (8.2%)
# Results for Exp-53: Accuracy=82.40%, Recall=82.32%, F1=82.20%
# ----------------------------------------
# Running Exp-54 of 648 (8.3%)
# Results for Exp-54: Accuracy=84.32%, Recall=84.28%, F1=84.20%
# ----------------------------------------
# Running Exp-55 of 648 (8.5%)
# Results for Exp-55: Accuracy=81.03%, Recall=80.79%, F1=80.94%
# ----------------------------------------
# Running Exp-56 of 648 (8.6%)
# Results for Exp-56: Accuracy=80.14%, Recall=79.76%, F1=80.11%
# ----------------------------------------
# Running Exp-57 of 648 (8.8%)
# Results for Exp-57: Accuracy=81.51%, Recall=81.25%, F1=81.27%
# ----------------------------------------
# Running Exp-58 of 648 (9.0%)
# Results for Exp-58: Accuracy=84.32%, Recall=84.10%, F1=84.24%
# ----------------------------------------
# Running Exp-59 of 648 (9.1%)
# Results for Exp-59: Accuracy=84.97%, Recall=84.89%, F1=84.85%
# ----------------------------------------
# Running Exp-60 of 648 (9.3%)
# Results for Exp-60: Accuracy=83.52%, Recall=83.20%, F1=83.42%
# ----------------------------------------
# Running Exp-61 of 648 (9.4%)
# Results for Exp-61: Accuracy=81.11%, Recall=80.97%, F1=81.08%
# ----------------------------------------
# Running Exp-62 of 648 (9.6%)
# Results for Exp-62: Accuracy=80.87%, Recall=80.74%, F1=80.70%
# ----------------------------------------
# Running Exp-63 of 648 (9.7%)
# Results for Exp-63: Accuracy=79.42%, Recall=79.32%, F1=78.90%
# ----------------------------------------
# Running Exp-64 of 648 (9.9%)
# Results for Exp-64: Accuracy=83.60%, Recall=83.46%, F1=83.53%
# ----------------------------------------
# Running Exp-65 of 648 (10.0%)
# Results for Exp-65: Accuracy=82.64%, Recall=82.69%, F1=82.58%
# ----------------------------------------
# Running Exp-66 of 648 (10.2%)
# Results for Exp-66: Accuracy=82.64%, Recall=82.83%, F1=82.40%
# ----------------------------------------
# Running Exp-67 of 648 (10.3%)
# Results for Exp-67: Accuracy=78.38%, Recall=78.45%, F1=77.94%
# ----------------------------------------
# Running Exp-68 of 648 (10.5%)
# Results for Exp-68: Accuracy=78.94%, Recall=79.02%, F1=78.76%
# ----------------------------------------
# Running Exp-69 of 648 (10.6%)
# Results for Exp-69: Accuracy=80.31%, Recall=80.01%, F1=80.06%
# ----------------------------------------
# Running Exp-70 of 648 (10.8%)
# Results for Exp-70: Accuracy=82.23%, Recall=82.37%, F1=82.09%
# ----------------------------------------
# Running Exp-71 of 648 (11.0%)
# Results for Exp-71: Accuracy=82.72%, Recall=82.46%, F1=82.64%
# ----------------------------------------
# Running Exp-72 of 648 (11.1%)
# Results for Exp-72: Accuracy=81.75%, Recall=81.73%, F1=81.69%
# ----------------------------------------
# Running Exp-73 of 648 (11.3%)
# Results for Exp-73: Accuracy=83.12%, Recall=82.98%, F1=83.06%
# ----------------------------------------
# Running Exp-74 of 648 (11.4%)
# Results for Exp-74: Accuracy=82.07%, Recall=81.77%, F1=82.07%
# ----------------------------------------
# Running Exp-75 of 648 (11.6%)
# Results for Exp-75: Accuracy=82.40%, Recall=82.12%, F1=82.25%
# ----------------------------------------
# Running Exp-76 of 648 (11.7%)
# Results for Exp-76: Accuracy=84.24%, Recall=84.19%, F1=84.24%
# ----------------------------------------
# Running Exp-77 of 648 (11.9%)
# Results for Exp-77: Accuracy=84.32%, Recall=84.19%, F1=84.26%
# ----------------------------------------
# Running Exp-78 of 648 (12.0%)
# Results for Exp-78: Accuracy=84.57%, Recall=84.27%, F1=84.45%
# ----------------------------------------
# Running Exp-79 of 648 (12.2%)
# Results for Exp-79: Accuracy=81.67%, Recall=81.31%, F1=81.60%
# ----------------------------------------
# Running Exp-80 of 648 (12.3%)
# Results for Exp-80: Accuracy=82.56%, Recall=82.27%, F1=82.37%
# ----------------------------------------
# Running Exp-81 of 648 (12.5%)
# Results for Exp-81: Accuracy=80.79%, Recall=80.60%, F1=80.66%
# ----------------------------------------
# Running Exp-82 of 648 (12.7%)
# Results for Exp-82: Accuracy=84.41%, Recall=84.40%, F1=84.36%
# ----------------------------------------
# Running Exp-83 of 648 (12.8%)
# Results for Exp-83: Accuracy=83.76%, Recall=83.94%, F1=83.64%
# ----------------------------------------
# Running Exp-84 of 648 (13.0%)
# Results for Exp-84: Accuracy=84.00%, Recall=84.06%, F1=83.94%
# ----------------------------------------
# Running Exp-85 of 648 (13.1%)
# Results for Exp-85: Accuracy=82.15%, Recall=82.15%, F1=82.07%
# ----------------------------------------
# Running Exp-86 of 648 (13.3%)
# Results for Exp-86: Accuracy=81.67%, Recall=81.90%, F1=81.68%
# ----------------------------------------
# Running Exp-87 of 648 (13.4%)
# Results for Exp-87: Accuracy=79.42%, Recall=79.24%, F1=79.04%
# ----------------------------------------
# Running Exp-88 of 648 (13.6%)
# Results for Exp-88: Accuracy=82.56%, Recall=82.59%, F1=82.59%
# ----------------------------------------
# Running Exp-89 of 648 (13.7%)
# Results for Exp-89: Accuracy=82.72%, Recall=82.66%, F1=82.64%
# ----------------------------------------
# Running Exp-90 of 648 (13.9%)
# Results for Exp-90: Accuracy=83.12%, Recall=83.14%, F1=82.98%
# ----------------------------------------
# Running Exp-91 of 648 (14.0%)
# Results for Exp-91: Accuracy=74.76%, Recall=74.90%, F1=73.50%
# ----------------------------------------
# Running Exp-92 of 648 (14.2%)
# Results for Exp-92: Accuracy=74.84%, Recall=74.86%, F1=73.36%
# ----------------------------------------
# Running Exp-93 of 648 (14.4%)
# Results for Exp-93: Accuracy=76.13%, Recall=75.97%, F1=75.42%
# ----------------------------------------
# Running Exp-94 of 648 (14.5%)
# Results for Exp-94: Accuracy=78.05%, Recall=78.39%, F1=77.24%
# ----------------------------------------
# Running Exp-95 of 648 (14.7%)
# Results for Exp-95: Accuracy=77.17%, Recall=77.34%, F1=76.23%
# ----------------------------------------
# Running Exp-96 of 648 (14.8%)
# Results for Exp-96: Accuracy=76.21%, Recall=76.58%, F1=75.44%
# ----------------------------------------
# Running Exp-97 of 648 (15.0%)
# Results for Exp-97: Accuracy=81.67%, Recall=81.16%, F1=81.30%
# ----------------------------------------
# Running Exp-98 of 648 (15.1%)
# Results for Exp-98: Accuracy=83.12%, Recall=82.99%, F1=83.01%
# ----------------------------------------
# Running Exp-99 of 648 (15.3%)
# Results for Exp-99: Accuracy=83.04%, Recall=83.01%, F1=82.93%
# ----------------------------------------
# Running Exp-100 of 648 (15.4%)
# Results for Exp-100: Accuracy=83.92%, Recall=83.92%, F1=83.92%
# ----------------------------------------
# Running Exp-101 of 648 (15.6%)
# Results for Exp-101: Accuracy=85.21%, Recall=84.79%, F1=85.05%
# ----------------------------------------
# Running Exp-102 of 648 (15.7%)
# Results for Exp-102: Accuracy=84.16%, Recall=84.04%, F1=84.04%
# ----------------------------------------
# Running Exp-103 of 648 (15.9%)
# Results for Exp-103: Accuracy=83.36%, Recall=83.28%, F1=83.28%
# ----------------------------------------
# Running Exp-104 of 648 (16.0%)
# Results for Exp-104: Accuracy=82.07%, Recall=82.12%, F1=81.76%
# ----------------------------------------
# Running Exp-105 of 648 (16.2%)
# Results for Exp-105: Accuracy=81.35%, Recall=81.12%, F1=81.20%
# ----------------------------------------
# Running Exp-106 of 648 (16.4%)
# Results for Exp-106: Accuracy=85.13%, Recall=85.06%, F1=85.15%
# ----------------------------------------
# Running Exp-107 of 648 (16.5%)
# Results for Exp-107: Accuracy=84.00%, Recall=84.02%, F1=84.01%
# ----------------------------------------
# Running Exp-108 of 648 (16.7%)
# Results for Exp-108: Accuracy=84.81%, Recall=84.97%, F1=84.62%
# ----------------------------------------
# Running Exp-109 of 648 (16.8%)
# Results for Exp-109: Accuracy=81.19%, Recall=81.46%, F1=81.04%
# ----------------------------------------
# Running Exp-110 of 648 (17.0%)
# Results for Exp-110: Accuracy=81.99%, Recall=81.80%, F1=81.83%
# ----------------------------------------
# Running Exp-111 of 648 (17.1%)
# Results for Exp-111: Accuracy=81.75%, Recall=81.73%, F1=81.56%
# ----------------------------------------
# Running Exp-112 of 648 (17.3%)
# Results for Exp-112: Accuracy=83.84%, Recall=83.69%, F1=83.71%
# ----------------------------------------
# Running Exp-113 of 648 (17.4%)
# Results for Exp-113: Accuracy=82.88%, Recall=82.92%, F1=82.61%
# ----------------------------------------
# Running Exp-114 of 648 (17.6%)
# Results for Exp-114: Accuracy=84.08%, Recall=84.12%, F1=84.03%
# ----------------------------------------
# Running Exp-115 of 648 (17.7%)
# Results for Exp-115: Accuracy=78.22%, Recall=77.73%, F1=77.90%
# ----------------------------------------
# Running Exp-116 of 648 (17.9%)
# Results for Exp-116: Accuracy=77.97%, Recall=77.80%, F1=77.50%
# ----------------------------------------
# Running Exp-117 of 648 (18.1%)
# Results for Exp-117: Accuracy=78.30%, Recall=77.66%, F1=78.03%
# ----------------------------------------
# Running Exp-118 of 648 (18.2%)
# Results for Exp-118: Accuracy=82.23%, Recall=82.29%, F1=82.17%
# ----------------------------------------
# Running Exp-119 of 648 (18.4%)
# Results for Exp-119: Accuracy=81.59%, Recall=81.68%, F1=81.51%
# ----------------------------------------
# Running Exp-120 of 648 (18.5%)
# Results for Exp-120: Accuracy=81.91%, Recall=81.95%, F1=81.72%
# ----------------------------------------
# Running Exp-121 of 648 (18.7%)
# Results for Exp-121: Accuracy=82.80%, Recall=82.92%, F1=82.74%
# ----------------------------------------
# Running Exp-122 of 648 (18.8%)
# Results for Exp-122: Accuracy=82.96%, Recall=82.96%, F1=82.90%
# ----------------------------------------
# Running Exp-123 of 648 (19.0%)
# Results for Exp-123: Accuracy=83.28%, Recall=83.26%, F1=83.05%
# ----------------------------------------
# Running Exp-124 of 648 (19.1%)
# Results for Exp-124: Accuracy=83.92%, Recall=83.91%, F1=83.83%
# ----------------------------------------
# Running Exp-125 of 648 (19.3%)
# Results for Exp-125: Accuracy=84.16%, Recall=84.30%, F1=83.90%
# ----------------------------------------
# Running Exp-126 of 648 (19.4%)
# Results for Exp-126: Accuracy=84.41%, Recall=84.30%, F1=84.36%
# ----------------------------------------
# Running Exp-127 of 648 (19.6%)
# Results for Exp-127: Accuracy=83.12%, Recall=83.12%, F1=83.01%
# ----------------------------------------
# Running Exp-128 of 648 (19.8%)
# Results for Exp-128: Accuracy=81.91%, Recall=81.95%, F1=81.91%
# ----------------------------------------
# Running Exp-129 of 648 (19.9%)
# Results for Exp-129: Accuracy=81.99%, Recall=81.82%, F1=81.79%
# ----------------------------------------
# Running Exp-130 of 648 (20.1%)
# Results for Exp-130: Accuracy=83.76%, Recall=83.81%, F1=83.84%
# ----------------------------------------
# Running Exp-131 of 648 (20.2%)
# Results for Exp-131: Accuracy=82.32%, Recall=82.26%, F1=82.21%
# ----------------------------------------
# Running Exp-132 of 648 (20.4%)
# Results for Exp-132: Accuracy=84.41%, Recall=84.41%, F1=84.31%
# ----------------------------------------
# Running Exp-133 of 648 (20.5%)
# Results for Exp-133: Accuracy=81.11%, Recall=80.93%, F1=80.90%
# ----------------------------------------
# Running Exp-134 of 648 (20.7%)
# Results for Exp-134: Accuracy=80.55%, Recall=80.64%, F1=80.22%
# ----------------------------------------
# Running Exp-135 of 648 (20.8%)
# Results for Exp-135: Accuracy=79.66%, Recall=79.10%, F1=79.62%
# ----------------------------------------
# Running Exp-136 of 648 (21.0%)
# Results for Exp-136: Accuracy=82.96%, Recall=82.70%, F1=82.96%
# ----------------------------------------
# Running Exp-137 of 648 (21.1%)
# Results for Exp-137: Accuracy=82.48%, Recall=82.54%, F1=82.49%
# ----------------------------------------
# Running Exp-138 of 648 (21.3%)
# Results for Exp-138: Accuracy=82.72%, Recall=82.71%, F1=82.60%
# ----------------------------------------
# Running Exp-139 of 648 (21.5%)
# Results for Exp-139: Accuracy=80.06%, Recall=80.04%, F1=79.86%
# ----------------------------------------
# Running Exp-140 of 648 (21.6%)
# Results for Exp-140: Accuracy=78.78%, Recall=78.59%, F1=78.46%
# ----------------------------------------
# Running Exp-141 of 648 (21.8%)
# Results for Exp-141: Accuracy=77.01%, Recall=76.86%, F1=76.67%
# ----------------------------------------
# Running Exp-142 of 648 (21.9%)
# Results for Exp-142: Accuracy=82.32%, Recall=82.28%, F1=82.12%
# ----------------------------------------
# Running Exp-143 of 648 (22.1%)
# Results for Exp-143: Accuracy=81.83%, Recall=81.80%, F1=81.67%
# ----------------------------------------
# Running Exp-144 of 648 (22.2%)
# Results for Exp-144: Accuracy=81.83%, Recall=81.88%, F1=81.62%
# ----------------------------------------
# Running Exp-145 of 648 (22.4%)
# Results for Exp-145: Accuracy=80.39%, Recall=80.20%, F1=80.12%
# ----------------------------------------
# Running Exp-146 of 648 (22.5%)
# Results for Exp-146: Accuracy=81.99%, Recall=81.61%, F1=81.87%
# ----------------------------------------
# Running Exp-147 of 648 (22.7%)
# Results for Exp-147: Accuracy=81.67%, Recall=81.88%, F1=81.71%
# ----------------------------------------
# Running Exp-148 of 648 (22.8%)
# Results for Exp-148: Accuracy=83.44%, Recall=83.34%, F1=83.28%
# ----------------------------------------
# Running Exp-149 of 648 (23.0%)
# Results for Exp-149: Accuracy=82.80%, Recall=82.68%, F1=82.69%
# ----------------------------------------
# Running Exp-150 of 648 (23.1%)
# Results for Exp-150: Accuracy=85.05%, Recall=85.21%, F1=84.96%
# ----------------------------------------
# Running Exp-151 of 648 (23.3%)
# Results for Exp-151: Accuracy=81.11%, Recall=81.18%, F1=80.84%
# ----------------------------------------
# Running Exp-152 of 648 (23.5%)
# Results for Exp-152: Accuracy=80.06%, Recall=80.05%, F1=79.71%
# ----------------------------------------
# Running Exp-153 of 648 (23.6%)
# Results for Exp-153: Accuracy=80.63%, Recall=80.65%, F1=80.17%
# ----------------------------------------
# Running Exp-154 of 648 (23.8%)
# Results for Exp-154: Accuracy=82.64%, Recall=82.78%, F1=82.53%
# ----------------------------------------
# Running Exp-155 of 648 (23.9%)
# Results for Exp-155: Accuracy=82.96%, Recall=82.97%, F1=82.68%
# ----------------------------------------
# Running Exp-156 of 648 (24.1%)
# Results for Exp-156: Accuracy=83.76%, Recall=83.88%, F1=83.60%
# ----------------------------------------
# Running Exp-157 of 648 (24.2%)
# Results for Exp-157: Accuracy=78.70%, Recall=78.83%, F1=78.24%
# ----------------------------------------
# Running Exp-158 of 648 (24.4%)
# Results for Exp-158: Accuracy=76.61%, Recall=77.02%, F1=75.53%
# ----------------------------------------
# Running Exp-159 of 648 (24.5%)
# Results for Exp-159: Accuracy=77.01%, Recall=77.20%, F1=76.05%
# ----------------------------------------
# Running Exp-160 of 648 (24.7%)
# Results for Exp-160: Accuracy=80.47%, Recall=80.47%, F1=80.15%
# ----------------------------------------
# Running Exp-161 of 648 (24.8%)
# Results for Exp-161: Accuracy=81.19%, Recall=81.20%, F1=80.94%
# ----------------------------------------
# Running Exp-162 of 648 (25.0%)
# Results for Exp-162: Accuracy=80.79%, Recall=80.66%, F1=80.53%
# ----------------------------------------
# Running Exp-163 of 648 (25.2%)
# Results for Exp-163: Accuracy=71.14%, Recall=70.81%, F1=70.14%
# ----------------------------------------
# Running Exp-164 of 648 (25.3%)
# Results for Exp-164: Accuracy=68.97%, Recall=69.16%, F1=67.70%
# ----------------------------------------
# Running Exp-165 of 648 (25.5%)
# Results for Exp-165: Accuracy=70.82%, Recall=70.25%, F1=69.62%
# ----------------------------------------
# Running Exp-166 of 648 (25.6%)
# Results for Exp-166: Accuracy=73.15%, Recall=73.17%, F1=71.53%
# ----------------------------------------
# Running Exp-167 of 648 (25.8%)
# Results for Exp-167: Accuracy=73.63%, Recall=73.41%, F1=72.85%
# ----------------------------------------
# Running Exp-168 of 648 (25.9%)
# Results for Exp-168: Accuracy=74.60%, Recall=74.92%, F1=73.91%
# ----------------------------------------
# Running Exp-169 of 648 (26.1%)
# Results for Exp-169: Accuracy=81.51%, Recall=81.31%, F1=81.30%
# ----------------------------------------
# Running Exp-170 of 648 (26.2%)
# Results for Exp-170: Accuracy=82.72%, Recall=82.61%, F1=82.51%
# ----------------------------------------
# Running Exp-171 of 648 (26.4%)
# Results for Exp-171: Accuracy=81.75%, Recall=81.83%, F1=81.54%
# ----------------------------------------
# Running Exp-172 of 648 (26.5%)
# Results for Exp-172: Accuracy=84.89%, Recall=84.87%, F1=84.72%
# ----------------------------------------
# Running Exp-173 of 648 (26.7%)
# Results for Exp-173: Accuracy=84.97%, Recall=85.01%, F1=84.95%
# ----------------------------------------
# Running Exp-174 of 648 (26.9%)
# Results for Exp-174: Accuracy=84.16%, Recall=83.86%, F1=84.04%
# ----------------------------------------
# Running Exp-175 of 648 (27.0%)
# Results for Exp-175: Accuracy=81.99%, Recall=82.20%, F1=81.63%
# ----------------------------------------
# Running Exp-176 of 648 (27.2%)
# Results for Exp-176: Accuracy=80.63%, Recall=80.66%, F1=80.47%
# ----------------------------------------
# Running Exp-177 of 648 (27.3%)
# Results for Exp-177: Accuracy=81.83%, Recall=81.33%, F1=81.77%
# ----------------------------------------
# Running Exp-178 of 648 (27.5%)
# Results for Exp-178: Accuracy=84.41%, Recall=84.44%, F1=84.21%
# ----------------------------------------
# Running Exp-179 of 648 (27.6%)
# Results for Exp-179: Accuracy=84.41%, Recall=84.44%, F1=84.43%
# ----------------------------------------
# Running Exp-180 of 648 (27.8%)
# Results for Exp-180: Accuracy=83.60%, Recall=83.41%, F1=83.50%
# ----------------------------------------
# Running Exp-181 of 648 (27.9%)
# Results for Exp-181: Accuracy=79.98%, Recall=79.56%, F1=79.81%
# ----------------------------------------
# Running Exp-182 of 648 (28.1%)
# Results for Exp-182: Accuracy=80.06%, Recall=79.96%, F1=79.84%
# ----------------------------------------
# Running Exp-183 of 648 (28.2%)
# Results for Exp-183: Accuracy=80.06%, Recall=79.87%, F1=80.06%
# ----------------------------------------
# Running Exp-184 of 648 (28.4%)
# Results for Exp-184: Accuracy=83.28%, Recall=83.51%, F1=83.30%
# ----------------------------------------
# Running Exp-185 of 648 (28.5%)
# Results for Exp-185: Accuracy=83.04%, Recall=83.17%, F1=82.80%
# ----------------------------------------
# Running Exp-186 of 648 (28.7%)
# Results for Exp-186: Accuracy=82.32%, Recall=82.24%, F1=82.25%
# ----------------------------------------
# Running Exp-187 of 648 (28.9%)
# Results for Exp-187: Accuracy=72.27%, Recall=72.58%, F1=70.36%
# ----------------------------------------
# Running Exp-188 of 648 (29.0%)
# Results for Exp-188: Accuracy=76.53%, Recall=76.85%, F1=75.58%
# ----------------------------------------
# Running Exp-189 of 648 (29.2%)
# Results for Exp-189: Accuracy=72.35%, Recall=72.54%, F1=70.20%
# ----------------------------------------
# Running Exp-190 of 648 (29.3%)
# Results for Exp-190: Accuracy=76.37%, Recall=76.77%, F1=74.87%
# ----------------------------------------
# Running Exp-191 of 648 (29.5%)
# Results for Exp-191: Accuracy=76.69%, Recall=77.11%, F1=75.83%
# ----------------------------------------
# Running Exp-192 of 648 (29.6%)
# Results for Exp-192: Accuracy=78.38%, Recall=78.71%, F1=77.73%
# ----------------------------------------
# Running Exp-193 of 648 (29.8%)
# Results for Exp-193: Accuracy=79.26%, Recall=78.78%, F1=79.03%
# ----------------------------------------
# Running Exp-194 of 648 (29.9%)
# Results for Exp-194: Accuracy=83.36%, Recall=83.49%, F1=83.32%
# ----------------------------------------
# Running Exp-195 of 648 (30.1%)
# Results for Exp-195: Accuracy=81.75%, Recall=81.81%, F1=81.68%
# ----------------------------------------
# Running Exp-196 of 648 (30.2%)
# Results for Exp-196: Accuracy=84.65%, Recall=84.82%, F1=84.63%
# ----------------------------------------
# Running Exp-197 of 648 (30.4%)
# Results for Exp-197: Accuracy=83.28%, Recall=83.20%, F1=83.16%
# ----------------------------------------
# Running Exp-198 of 648 (30.6%)
# Results for Exp-198: Accuracy=84.97%, Recall=85.01%, F1=84.86%
# ----------------------------------------
# Running Exp-199 of 648 (30.7%)
# Results for Exp-199: Accuracy=79.34%, Recall=79.07%, F1=79.06%
# ----------------------------------------
# Running Exp-200 of 648 (30.9%)
# Results for Exp-200: Accuracy=81.67%, Recall=81.73%, F1=81.53%
# ----------------------------------------
# Running Exp-201 of 648 (31.0%)
# Results for Exp-201: Accuracy=79.10%, Recall=78.50%, F1=78.99%
# ----------------------------------------
# Running Exp-202 of 648 (31.2%)
# Results for Exp-202: Accuracy=83.12%, Recall=83.24%, F1=83.14%
# ----------------------------------------
# Running Exp-203 of 648 (31.3%)
# Results for Exp-203: Accuracy=83.52%, Recall=83.38%, F1=83.42%
# ----------------------------------------
# Running Exp-204 of 648 (31.5%)
# Results for Exp-204: Accuracy=81.83%, Recall=81.98%, F1=81.79%
# ----------------------------------------
# Running Exp-205 of 648 (31.6%)
# Results for Exp-205: Accuracy=80.55%, Recall=80.25%, F1=80.41%
# ----------------------------------------
# Running Exp-206 of 648 (31.8%)
# Results for Exp-206: Accuracy=80.31%, Recall=80.29%, F1=80.31%
# ----------------------------------------
# Running Exp-207 of 648 (31.9%)
# Results for Exp-207: Accuracy=79.82%, Recall=79.76%, F1=79.70%
# ----------------------------------------
# Running Exp-208 of 648 (32.1%)
# Results for Exp-208: Accuracy=80.47%, Recall=80.06%, F1=80.31%
# ----------------------------------------
# Running Exp-209 of 648 (32.3%)
# Results for Exp-209: Accuracy=83.20%, Recall=83.35%, F1=83.06%
# ----------------------------------------
# Running Exp-210 of 648 (32.4%)
# Results for Exp-210: Accuracy=81.75%, Recall=81.87%, F1=81.62%
# ----------------------------------------
# Running Exp-211 of 648 (32.6%)
# Results for Exp-211: Accuracy=78.05%, Recall=77.95%, F1=77.48%
# ----------------------------------------
# Running Exp-212 of 648 (32.7%)
# Results for Exp-212: Accuracy=77.81%, Recall=77.48%, F1=77.40%
# ----------------------------------------
# Running Exp-213 of 648 (32.9%)
# Results for Exp-213: Accuracy=74.92%, Recall=74.69%, F1=74.13%
# ----------------------------------------
# Running Exp-214 of 648 (33.0%)
# Results for Exp-214: Accuracy=80.95%, Recall=80.90%, F1=80.76%
# ----------------------------------------
# Running Exp-215 of 648 (33.2%)
# Results for Exp-215: Accuracy=79.98%, Recall=79.91%, F1=79.74%
# ----------------------------------------
# Running Exp-216 of 648 (33.3%)
# Results for Exp-216: Accuracy=80.71%, Recall=80.87%, F1=80.45%
# ----------------------------------------
# Running Exp-217 of 648 (33.5%)
# Results for Exp-217: Accuracy=83.20%, Recall=83.00%, F1=82.99%
# ----------------------------------------
# Running Exp-218 of 648 (33.6%)
# Results for Exp-218: Accuracy=83.44%, Recall=83.15%, F1=83.34%
# ----------------------------------------
# Running Exp-219 of 648 (33.8%)
# Results for Exp-219: Accuracy=82.15%, Recall=81.83%, F1=81.84%
# ----------------------------------------
# Running Exp-220 of 648 (34.0%)
# Results for Exp-220: Accuracy=85.13%, Recall=85.02%, F1=84.99%
# ----------------------------------------
# Running Exp-221 of 648 (34.1%)
# Results for Exp-221: Accuracy=85.37%, Recall=85.27%, F1=85.22%
# ----------------------------------------
# Running Exp-222 of 648 (34.3%)
# Results for Exp-222: Accuracy=84.65%, Recall=84.61%, F1=84.50%
# ----------------------------------------
# Running Exp-223 of 648 (34.4%)
# Results for Exp-223: Accuracy=82.96%, Recall=82.79%, F1=82.76%
# ----------------------------------------
# Running Exp-224 of 648 (34.6%)
# Results for Exp-224: Accuracy=83.60%, Recall=83.73%, F1=83.46%
# ----------------------------------------
# Running Exp-225 of 648 (34.7%)
# Results for Exp-225: Accuracy=81.75%, Recall=81.42%, F1=81.69%
# ----------------------------------------
# Running Exp-226 of 648 (34.9%)
# Results for Exp-226: Accuracy=84.41%, Recall=84.27%, F1=84.33%
# ----------------------------------------
# Running Exp-227 of 648 (35.0%)
# Results for Exp-227: Accuracy=84.57%, Recall=84.25%, F1=84.43%
# ----------------------------------------
# Running Exp-228 of 648 (35.2%)
# Results for Exp-228: Accuracy=84.24%, Recall=84.20%, F1=84.19%
# ----------------------------------------
# Running Exp-229 of 648 (35.3%)
# Results for Exp-229: Accuracy=82.15%, Recall=82.03%, F1=82.03%
# ----------------------------------------
# Running Exp-230 of 648 (35.5%)
# Results for Exp-230: Accuracy=81.99%, Recall=81.89%, F1=81.66%
# ----------------------------------------
# Running Exp-231 of 648 (35.6%)
# Results for Exp-231: Accuracy=82.88%, Recall=82.88%, F1=82.75%
# ----------------------------------------
# Running Exp-232 of 648 (35.8%)
# Results for Exp-232: Accuracy=83.20%, Recall=83.24%, F1=83.14%
# ----------------------------------------
# Running Exp-233 of 648 (36.0%)
# Results for Exp-233: Accuracy=83.28%, Recall=83.14%, F1=83.22%
# ----------------------------------------
# Running Exp-234 of 648 (36.1%)
# Results for Exp-234: Accuracy=83.28%, Recall=82.98%, F1=83.13%
# ----------------------------------------
# Running Exp-235 of 648 (36.3%)
# Results for Exp-235: Accuracy=77.89%, Recall=77.94%, F1=77.29%
# ----------------------------------------
# Running Exp-236 of 648 (36.4%)
# Results for Exp-236: Accuracy=79.90%, Recall=79.75%, F1=79.58%
# ----------------------------------------
# Running Exp-237 of 648 (36.6%)
# Results for Exp-237: Accuracy=79.74%, Recall=79.59%, F1=79.33%
# ----------------------------------------
# Running Exp-238 of 648 (36.7%)
# Results for Exp-238: Accuracy=80.87%, Recall=80.99%, F1=80.93%
# ----------------------------------------
# Running Exp-239 of 648 (36.9%)
# Results for Exp-239: Accuracy=81.99%, Recall=81.81%, F1=82.09%
# ----------------------------------------
# Running Exp-240 of 648 (37.0%)
# Results for Exp-240: Accuracy=81.35%, Recall=81.32%, F1=81.27%
# ----------------------------------------
# Running Exp-241 of 648 (37.2%)
# Results for Exp-241: Accuracy=83.92%, Recall=83.85%, F1=83.80%
# ----------------------------------------
# Running Exp-242 of 648 (37.3%)
# Results for Exp-242: Accuracy=83.76%, Recall=83.35%, F1=83.63%
# ----------------------------------------
# Running Exp-243 of 648 (37.5%)
# Results for Exp-243: Accuracy=83.76%, Recall=83.54%, F1=83.70%
# ----------------------------------------
# Running Exp-244 of 648 (37.7%)
# Results for Exp-244: Accuracy=84.81%, Recall=84.58%, F1=84.58%
# ----------------------------------------
# Running Exp-245 of 648 (37.8%)
# Results for Exp-245: Accuracy=84.57%, Recall=84.32%, F1=84.43%
# ----------------------------------------
# Running Exp-246 of 648 (38.0%)
# Results for Exp-246: Accuracy=85.05%, Recall=84.84%, F1=84.99%
# ----------------------------------------
# Running Exp-247 of 648 (38.1%)
# Results for Exp-247: Accuracy=83.92%, Recall=83.76%, F1=83.78%
# ----------------------------------------
# Running Exp-248 of 648 (38.3%)
# Results for Exp-248: Accuracy=83.84%, Recall=83.62%, F1=83.81%
# ----------------------------------------
# Running Exp-249 of 648 (38.4%)
# Results for Exp-249: Accuracy=83.20%, Recall=83.06%, F1=83.08%
# ----------------------------------------
# Running Exp-250 of 648 (38.6%)
# Results for Exp-250: Accuracy=85.13%, Recall=85.00%, F1=85.01%
# ----------------------------------------
# Running Exp-251 of 648 (38.7%)
# Results for Exp-251: Accuracy=83.52%, Recall=83.41%, F1=83.42%
# ----------------------------------------
# Running Exp-252 of 648 (38.9%)
# Results for Exp-252: Accuracy=84.73%, Recall=84.48%, F1=84.56%
# ----------------------------------------
# Running Exp-253 of 648 (39.0%)
# Results for Exp-253: Accuracy=83.60%, Recall=83.42%, F1=83.52%
# ----------------------------------------
# Running Exp-254 of 648 (39.2%)
# Results for Exp-254: Accuracy=83.36%, Recall=83.17%, F1=83.21%
# ----------------------------------------
# Running Exp-255 of 648 (39.4%)
# Results for Exp-255: Accuracy=81.91%, Recall=81.63%, F1=81.65%
# ----------------------------------------
# Running Exp-256 of 648 (39.5%)
# Results for Exp-256: Accuracy=85.21%, Recall=85.00%, F1=85.13%
# ----------------------------------------
# Running Exp-257 of 648 (39.7%)
# Results for Exp-257: Accuracy=84.16%, Recall=84.08%, F1=84.03%
# ----------------------------------------
# Running Exp-258 of 648 (39.8%)
# Results for Exp-258: Accuracy=83.84%, Recall=83.57%, F1=83.78%
# ----------------------------------------
# Running Exp-259 of 648 (40.0%)
# Results for Exp-259: Accuracy=82.15%, Recall=81.99%, F1=82.09%
# ----------------------------------------
# Running Exp-260 of 648 (40.1%)
# Results for Exp-260: Accuracy=82.23%, Recall=82.14%, F1=82.10%
# ----------------------------------------
# Running Exp-261 of 648 (40.3%)
# Results for Exp-261: Accuracy=80.79%, Recall=80.23%, F1=80.59%
# ----------------------------------------
# Running Exp-262 of 648 (40.4%)
# Results for Exp-262: Accuracy=83.76%, Recall=83.61%, F1=83.56%
# ----------------------------------------
# Running Exp-263 of 648 (40.6%)
# Results for Exp-263: Accuracy=83.60%, Recall=83.41%, F1=83.51%
# ----------------------------------------
# Running Exp-264 of 648 (40.7%)
# Results for Exp-264: Accuracy=83.44%, Recall=83.55%, F1=83.45%
# ----------------------------------------
# Running Exp-265 of 648 (40.9%)
# Results for Exp-265: Accuracy=84.08%, Recall=83.93%, F1=83.95%
# ----------------------------------------
# Running Exp-266 of 648 (41.0%)
# Results for Exp-266: Accuracy=84.00%, Recall=83.96%, F1=83.91%
# ----------------------------------------
# Running Exp-267 of 648 (41.2%)
# Results for Exp-267: Accuracy=83.36%, Recall=83.38%, F1=83.40%
# ----------------------------------------
# Running Exp-268 of 648 (41.4%)
# Results for Exp-268: Accuracy=84.16%, Recall=83.96%, F1=83.98%
# ----------------------------------------
# Running Exp-269 of 648 (41.5%)
# Results for Exp-269: Accuracy=85.05%, Recall=85.03%, F1=84.88%
# ----------------------------------------
# Running Exp-270 of 648 (41.7%)
# Results for Exp-270: Accuracy=85.61%, Recall=85.43%, F1=85.54%
# ----------------------------------------
# Running Exp-271 of 648 (41.8%)
# Results for Exp-271: Accuracy=84.08%, Recall=84.14%, F1=84.02%
# ----------------------------------------
# Running Exp-272 of 648 (42.0%)
# Results for Exp-272: Accuracy=83.84%, Recall=83.68%, F1=83.76%
# ----------------------------------------
# Running Exp-273 of 648 (42.1%)
# Results for Exp-273: Accuracy=82.48%, Recall=82.24%, F1=82.25%
# ----------------------------------------
# Running Exp-274 of 648 (42.3%)
# Results for Exp-274: Accuracy=85.05%, Recall=84.94%, F1=84.99%
# ----------------------------------------
# Running Exp-275 of 648 (42.4%)
# Results for Exp-275: Accuracy=83.92%, Recall=83.63%, F1=83.79%
# ----------------------------------------
# Running Exp-276 of 648 (42.6%)
# Results for Exp-276: Accuracy=85.69%, Recall=85.59%, F1=85.66%
# ----------------------------------------
# Running Exp-277 of 648 (42.7%)
# Results for Exp-277: Accuracy=83.20%, Recall=83.16%, F1=82.92%
# ----------------------------------------
# Running Exp-278 of 648 (42.9%)
# Results for Exp-278: Accuracy=82.88%, Recall=82.95%, F1=82.63%
# ----------------------------------------
# Running Exp-279 of 648 (43.1%)
# Results for Exp-279: Accuracy=83.20%, Recall=83.15%, F1=83.03%
# ----------------------------------------
# Running Exp-280 of 648 (43.2%)
# Results for Exp-280: Accuracy=85.05%, Recall=84.80%, F1=84.94%
# ----------------------------------------
# Running Exp-281 of 648 (43.4%)
# Results for Exp-281: Accuracy=85.13%, Recall=85.03%, F1=85.08%
# ----------------------------------------
# Running Exp-282 of 648 (43.5%)
# Results for Exp-282: Accuracy=84.97%, Recall=84.79%, F1=84.83%
# ----------------------------------------
# Running Exp-283 of 648 (43.7%)
# Results for Exp-283: Accuracy=81.35%, Recall=81.46%, F1=81.03%
# ----------------------------------------
# Running Exp-284 of 648 (43.8%)
# Results for Exp-284: Accuracy=82.40%, Recall=82.05%, F1=82.19%
# ----------------------------------------
# Running Exp-285 of 648 (44.0%)
# Results for Exp-285: Accuracy=82.64%, Recall=82.69%, F1=82.42%
# ----------------------------------------
# Running Exp-286 of 648 (44.1%)
# Results for Exp-286: Accuracy=83.84%, Recall=83.73%, F1=83.66%
# ----------------------------------------
# Running Exp-287 of 648 (44.3%)
# Results for Exp-287: Accuracy=83.36%, Recall=83.29%, F1=83.17%
# ----------------------------------------
# Running Exp-288 of 648 (44.4%)
# Results for Exp-288: Accuracy=83.76%, Recall=83.69%, F1=83.67%
# ----------------------------------------
# Running Exp-289 of 648 (44.6%)
# Results for Exp-289: Accuracy=83.52%, Recall=83.32%, F1=83.30%
# ----------------------------------------
# Running Exp-290 of 648 (44.8%)
# Results for Exp-290: Accuracy=84.49%, Recall=84.40%, F1=84.43%
# ----------------------------------------
# Running Exp-291 of 648 (44.9%)
# Results for Exp-291: Accuracy=84.24%, Recall=84.14%, F1=84.20%
# ----------------------------------------
# Running Exp-292 of 648 (45.1%)
# Results for Exp-292: Accuracy=85.69%, Recall=85.61%, F1=85.65%
# ----------------------------------------
# Running Exp-293 of 648 (45.2%)
# Results for Exp-293: Accuracy=86.66%, Recall=86.60%, F1=86.58%
# ----------------------------------------
# Running Exp-294 of 648 (45.4%)
# Results for Exp-294: Accuracy=84.81%, Recall=84.58%, F1=84.72%
# ----------------------------------------
# Running Exp-295 of 648 (45.5%)
# Results for Exp-295: Accuracy=83.52%, Recall=83.47%, F1=83.36%
# ----------------------------------------
# Running Exp-296 of 648 (45.7%)
# Results for Exp-296: Accuracy=82.88%, Recall=82.72%, F1=82.65%
# ----------------------------------------
# Running Exp-297 of 648 (45.8%)
# Results for Exp-297: Accuracy=82.64%, Recall=82.38%, F1=82.51%
# ----------------------------------------
# Running Exp-298 of 648 (46.0%)
# Results for Exp-298: Accuracy=85.05%, Recall=84.97%, F1=85.05%
# ----------------------------------------
# Running Exp-299 of 648 (46.1%)
# Results for Exp-299: Accuracy=84.08%, Recall=83.97%, F1=84.07%
# ----------------------------------------
# Running Exp-300 of 648 (46.3%)
# Results for Exp-300: Accuracy=84.89%, Recall=84.86%, F1=84.85%
# ----------------------------------------
# Running Exp-301 of 648 (46.5%)
# Results for Exp-301: Accuracy=81.83%, Recall=81.55%, F1=81.64%
# ----------------------------------------
# Running Exp-302 of 648 (46.6%)
# Results for Exp-302: Accuracy=81.99%, Recall=81.95%, F1=81.73%
# ----------------------------------------
# Running Exp-303 of 648 (46.8%)
# Results for Exp-303: Accuracy=81.27%, Recall=80.91%, F1=81.13%
# ----------------------------------------
# Running Exp-304 of 648 (46.9%)
# Results for Exp-304: Accuracy=83.44%, Recall=83.52%, F1=83.36%
# ----------------------------------------
# Running Exp-305 of 648 (47.1%)
# Results for Exp-305: Accuracy=82.40%, Recall=82.21%, F1=82.36%
# ----------------------------------------
# Running Exp-306 of 648 (47.2%)
# Results for Exp-306: Accuracy=83.68%, Recall=83.65%, F1=83.62%
# ----------------------------------------
# Running Exp-307 of 648 (47.4%)
# Results for Exp-307: Accuracy=77.57%, Recall=77.51%, F1=76.75%
# ----------------------------------------
# Running Exp-308 of 648 (47.5%)
# Results for Exp-308: Accuracy=77.81%, Recall=77.97%, F1=76.95%
# ----------------------------------------
# Running Exp-309 of 648 (47.7%)
# Results for Exp-309: Accuracy=77.17%, Recall=77.15%, F1=76.38%
# ----------------------------------------
# Running Exp-310 of 648 (47.8%)
# Results for Exp-310: Accuracy=77.89%, Recall=78.11%, F1=77.25%
# ----------------------------------------
# Running Exp-311 of 648 (48.0%)
# Results for Exp-311: Accuracy=78.30%, Recall=78.26%, F1=77.76%
# ----------------------------------------
# Running Exp-312 of 648 (48.1%)
# Results for Exp-312: Accuracy=80.39%, Recall=80.40%, F1=80.05%
# ----------------------------------------
# Running Exp-313 of 648 (48.3%)
# Results for Exp-313: Accuracy=83.12%, Recall=83.11%, F1=82.89%
# ----------------------------------------
# Running Exp-314 of 648 (48.5%)
# Results for Exp-314: Accuracy=84.32%, Recall=84.06%, F1=84.19%
# ----------------------------------------
# Running Exp-315 of 648 (48.6%)
# Results for Exp-315: Accuracy=84.97%, Recall=84.84%, F1=84.87%
# ----------------------------------------
# Running Exp-316 of 648 (48.8%)
# Results for Exp-316: Accuracy=86.17%, Recall=86.26%, F1=86.10%
# ----------------------------------------
# Running Exp-317 of 648 (48.9%)
# Results for Exp-317: Accuracy=86.50%, Recall=86.31%, F1=86.34%
# ----------------------------------------
# Running Exp-318 of 648 (49.1%)
# Results for Exp-318: Accuracy=87.62%, Recall=87.54%, F1=87.51%
# ----------------------------------------
# Running Exp-319 of 648 (49.2%)
# Results for Exp-319: Accuracy=84.49%, Recall=84.43%, F1=84.45%
# ----------------------------------------
# Running Exp-320 of 648 (49.4%)
# Results for Exp-320: Accuracy=84.32%, Recall=84.32%, F1=84.17%
# ----------------------------------------
# Running Exp-321 of 648 (49.5%)
# Results for Exp-321: Accuracy=83.60%, Recall=83.12%, F1=83.50%
# ----------------------------------------
# Running Exp-322 of 648 (49.7%)
# Results for Exp-322: Accuracy=84.49%, Recall=84.54%, F1=84.36%
# ----------------------------------------
# Running Exp-323 of 648 (49.8%)
# Results for Exp-323: Accuracy=86.82%, Recall=86.73%, F1=86.78%
# ----------------------------------------
# Running Exp-324 of 648 (50.0%)
# Results for Exp-324: Accuracy=85.53%, Recall=85.79%, F1=85.53%
# ----------------------------------------
# Running Exp-325 of 648 (50.2%)
# Results for Exp-325: Accuracy=83.28%, Recall=83.24%, F1=83.21%
# ----------------------------------------
# Running Exp-326 of 648 (50.3%)
# Results for Exp-326: Accuracy=81.43%, Recall=81.19%, F1=81.22%
# ----------------------------------------
# Running Exp-327 of 648 (50.5%)
# Results for Exp-327: Accuracy=82.56%, Recall=82.38%, F1=82.44%
# ----------------------------------------
# Running Exp-328 of 648 (50.6%)
# Results for Exp-328: Accuracy=85.29%, Recall=85.24%, F1=85.14%
# ----------------------------------------
# Running Exp-329 of 648 (50.8%)
# Results for Exp-329: Accuracy=84.32%, Recall=84.19%, F1=84.33%
# ----------------------------------------
# Running Exp-330 of 648 (50.9%)
# Results for Exp-330: Accuracy=83.84%, Recall=83.90%, F1=83.82%
# ----------------------------------------
# Running Exp-331 of 648 (51.1%)
# Results for Exp-331: Accuracy=81.43%, Recall=81.27%, F1=81.19%
# ----------------------------------------
# Running Exp-332 of 648 (51.2%)
# Results for Exp-332: Accuracy=79.10%, Recall=78.66%, F1=78.83%
# ----------------------------------------
# Running Exp-333 of 648 (51.4%)
# Results for Exp-333: Accuracy=80.63%, Recall=80.45%, F1=80.34%
# ----------------------------------------
# Running Exp-334 of 648 (51.5%)
# Results for Exp-334: Accuracy=82.32%, Recall=82.30%, F1=82.24%
# ----------------------------------------
# Running Exp-335 of 648 (51.7%)
# Results for Exp-335: Accuracy=82.40%, Recall=82.46%, F1=82.34%
# ----------------------------------------
# Running Exp-336 of 648 (51.9%)
# Results for Exp-336: Accuracy=83.20%, Recall=83.30%, F1=83.11%
# ----------------------------------------
# Running Exp-337 of 648 (52.0%)
# Results for Exp-337: Accuracy=83.20%, Recall=83.00%, F1=83.13%
# ----------------------------------------
# Running Exp-338 of 648 (52.2%)
# Results for Exp-338: Accuracy=84.81%, Recall=84.47%, F1=84.74%
# ----------------------------------------
# Running Exp-339 of 648 (52.3%)
# Results for Exp-339: Accuracy=85.69%, Recall=85.62%, F1=85.62%
# ----------------------------------------
# Running Exp-340 of 648 (52.5%)
# Results for Exp-340: Accuracy=86.82%, Recall=86.45%, F1=86.69%
# ----------------------------------------
# Running Exp-341 of 648 (52.6%)
# Results for Exp-341: Accuracy=86.58%, Recall=86.46%, F1=86.51%
# ----------------------------------------
# Running Exp-342 of 648 (52.8%)
# Results for Exp-342: Accuracy=85.93%, Recall=85.83%, F1=85.84%
# ----------------------------------------
# Running Exp-343 of 648 (52.9%)
# Results for Exp-343: Accuracy=83.68%, Recall=83.54%, F1=83.63%
# ----------------------------------------
# Running Exp-344 of 648 (53.1%)
# Results for Exp-344: Accuracy=84.65%, Recall=84.49%, F1=84.56%
# ----------------------------------------
# Running Exp-345 of 648 (53.2%)
# Results for Exp-345: Accuracy=84.16%, Recall=83.86%, F1=84.09%
# ----------------------------------------
# Running Exp-346 of 648 (53.4%)
# Results for Exp-346: Accuracy=84.49%, Recall=84.41%, F1=84.32%
# ----------------------------------------
# Running Exp-347 of 648 (53.5%)
# Results for Exp-347: Accuracy=85.85%, Recall=85.62%, F1=85.76%
# ----------------------------------------
# Running Exp-348 of 648 (53.7%)
# Results for Exp-348: Accuracy=85.37%, Recall=84.96%, F1=85.25%
# ----------------------------------------
# Running Exp-349 of 648 (53.9%)
# Results for Exp-349: Accuracy=82.96%, Recall=82.60%, F1=82.79%
# ----------------------------------------
# Running Exp-350 of 648 (54.0%)
# Results for Exp-350: Accuracy=84.41%, Recall=84.43%, F1=84.35%
# ----------------------------------------
# Running Exp-351 of 648 (54.2%)
# Results for Exp-351: Accuracy=83.20%, Recall=82.93%, F1=83.14%
# ----------------------------------------
# Running Exp-352 of 648 (54.3%)
# Results for Exp-352: Accuracy=84.16%, Recall=83.97%, F1=84.06%
# ----------------------------------------
# Running Exp-353 of 648 (54.5%)
# Results for Exp-353: Accuracy=85.13%, Recall=85.06%, F1=85.06%
# ----------------------------------------
# Running Exp-354 of 648 (54.6%)
# Results for Exp-354: Accuracy=84.73%, Recall=84.79%, F1=84.63%
# ----------------------------------------
# Running Exp-355 of 648 (54.8%)
# Results for Exp-355: Accuracy=82.72%, Recall=82.64%, F1=82.70%
# ----------------------------------------
# Running Exp-356 of 648 (54.9%)
# Results for Exp-356: Accuracy=81.43%, Recall=81.26%, F1=81.41%
# ----------------------------------------
# ...
# Results for Exp-575: Accuracy=84.41%, Recall=84.43%, F1=84.33%
# ----------------------------------------
# Running Exp-576 of 648 (88.9%)
# Results for Exp-576: Accuracy=84.49%, Recall=84.47%, F1=84.42%
# ----------------------------------------
# Running Exp-577 of 648 (89.0%)
# Results for Exp-577: Accuracy=82.88%, Recall=82.85%, F1=82.66%
# ----------------------------------------
# Running Exp-578 of 648 (89.2%)
# Results for Exp-578: Accuracy=84.08%, Recall=84.10%, F1=83.94%
# ----------------------------------------
# Running Exp-579 of 648 (89.4%)
# Results for Exp-579: Accuracy=83.68%, Recall=83.79%, F1=83.62%
# ----------------------------------------
# Running Exp-580 of 648 (89.5%)
# Results for Exp-580: Accuracy=82.88%, Recall=82.79%, F1=82.72%
# ----------------------------------------
# Running Exp-581 of 648 (89.7%)
# Results for Exp-581: Accuracy=84.89%, Recall=84.97%, F1=84.82%
# ----------------------------------------
# Running Exp-582 of 648 (89.8%)
# Results for Exp-582: Accuracy=85.05%, Recall=84.96%, F1=84.95%
# ----------------------------------------
# Running Exp-583 of 648 (90.0%)
# Results for Exp-583: Accuracy=78.14%, Recall=77.85%, F1=77.56%
# ----------------------------------------
# Running Exp-584 of 648 (90.1%)
# Results for Exp-584: Accuracy=82.32%, Recall=82.24%, F1=82.02%
# ----------------------------------------
# Running Exp-585 of 648 (90.3%)
# Results for Exp-585: Accuracy=82.56%, Recall=82.23%, F1=82.44%
# ----------------------------------------
# Running Exp-586 of 648 (90.4%)
# Results for Exp-586: Accuracy=77.57%, Recall=77.74%, F1=76.36%
# ----------------------------------------
# Running Exp-587 of 648 (90.6%)
# Results for Exp-587: Accuracy=84.08%, Recall=84.09%, F1=84.00%
# ----------------------------------------
# Running Exp-588 of 648 (90.7%)
# Results for Exp-588: Accuracy=84.49%, Recall=84.46%, F1=84.31%
# ----------------------------------------
# Running Exp-589 of 648 (90.9%)
# Results for Exp-589: Accuracy=72.99%, Recall=73.31%, F1=70.28%
# ----------------------------------------
# Running Exp-590 of 648 (91.0%)
# Results for Exp-590: Accuracy=79.50%, Recall=79.49%, F1=78.94%
# ----------------------------------------
# Running Exp-591 of 648 (91.2%)
# Results for Exp-591: Accuracy=77.33%, Recall=77.50%, F1=76.05%
# ----------------------------------------
# Running Exp-592 of 648 (91.4%)
# Results for Exp-592: Accuracy=74.20%, Recall=74.54%, F1=71.66%
# ----------------------------------------
# Running Exp-593 of 648 (91.5%)
# Results for Exp-593: Accuracy=79.58%, Recall=79.90%, F1=78.74%
# ----------------------------------------
# Running Exp-594 of 648 (91.7%)
# Results for Exp-594: Accuracy=82.72%, Recall=82.82%, F1=82.38%
# ----------------------------------------
# Running Exp-595 of 648 (91.8%)
# Results for Exp-595: Accuracy=48.07%, Recall=47.92%, F1=34.52%
# ----------------------------------------
# Running Exp-596 of 648 (92.0%)
# Results for Exp-596: Accuracy=61.66%, Recall=60.61%, F1=54.42%
# ----------------------------------------
# Running Exp-597 of 648 (92.1%)
# Results for Exp-597: Accuracy=71.54%, Recall=71.25%, F1=70.23%
# ----------------------------------------
# Running Exp-598 of 648 (92.3%)
# Results for Exp-598: Accuracy=57.64%, Recall=56.24%, F1=49.22%
# ----------------------------------------
# Running Exp-599 of 648 (92.4%)
# Results for Exp-599: Accuracy=69.29%, Recall=69.07%, F1=67.11%
# ----------------------------------------
# Running Exp-600 of 648 (92.6%)
# Results for Exp-600: Accuracy=73.79%, Recall=73.60%, F1=72.54%
# ----------------------------------------
# Running Exp-601 of 648 (92.7%)
# Results for Exp-601: Accuracy=84.24%, Recall=83.93%, F1=84.02%
# ----------------------------------------
# Running Exp-602 of 648 (92.9%)
# Results for Exp-602: Accuracy=84.41%, Recall=84.21%, F1=84.25%
# ----------------------------------------
# Running Exp-603 of 648 (93.1%)
# Results for Exp-603: Accuracy=84.24%, Recall=83.99%, F1=84.21%
# ----------------------------------------
# Running Exp-604 of 648 (93.2%)
# Results for Exp-604: Accuracy=84.41%, Recall=84.35%, F1=84.35%
# ----------------------------------------
# Running Exp-605 of 648 (93.4%)
# Results for Exp-605: Accuracy=87.14%, Recall=87.05%, F1=87.05%
# ----------------------------------------
# Running Exp-606 of 648 (93.5%)
# Results for Exp-606: Accuracy=86.25%, Recall=86.05%, F1=86.15%
# ----------------------------------------
# Running Exp-607 of 648 (93.7%)
# Results for Exp-607: Accuracy=83.76%, Recall=83.82%, F1=83.65%
# ----------------------------------------
# Running Exp-608 of 648 (93.8%)
# Results for Exp-608: Accuracy=85.45%, Recall=85.51%, F1=85.34%
# ----------------------------------------
# Running Exp-609 of 648 (94.0%)
# Results for Exp-609: Accuracy=84.65%, Recall=84.29%, F1=84.45%
# ----------------------------------------
# Running Exp-610 of 648 (94.1%)
# Results for Exp-610: Accuracy=84.32%, Recall=84.33%, F1=84.14%
# ----------------------------------------
# Running Exp-611 of 648 (94.3%)
# Results for Exp-611: Accuracy=85.45%, Recall=85.31%, F1=85.35%
# ----------------------------------------
# Running Exp-612 of 648 (94.4%)
# Results for Exp-612: Accuracy=85.37%, Recall=85.31%, F1=85.29%
# ----------------------------------------
# Running Exp-613 of 648 (94.6%)
# Results for Exp-613: Accuracy=81.51%, Recall=81.30%, F1=81.31%
# ----------------------------------------
# Running Exp-614 of 648 (94.8%)
# Results for Exp-614: Accuracy=83.20%, Recall=82.87%, F1=83.08%
# ----------------------------------------
# Running Exp-615 of 648 (94.9%)
# Results for Exp-615: Accuracy=83.36%, Recall=83.27%, F1=83.07%
# ----------------------------------------
# Running Exp-616 of 648 (95.1%)
# Results for Exp-616: Accuracy=81.51%, Recall=81.59%, F1=81.18%
# ----------------------------------------
# Running Exp-617 of 648 (95.2%)
# Results for Exp-617: Accuracy=83.84%, Recall=83.89%, F1=83.74%
# ----------------------------------------
# Running Exp-618 of 648 (95.4%)
# Results for Exp-618: Accuracy=85.13%, Recall=85.08%, F1=84.98%
# ----------------------------------------
# Running Exp-619 of 648 (95.5%)
# Results for Exp-619: Accuracy=61.98%, Recall=61.52%, F1=57.11%
# ----------------------------------------
# Running Exp-620 of 648 (95.7%)
# Results for Exp-620: Accuracy=75.40%, Recall=75.26%, F1=74.34%
# ----------------------------------------
# Running Exp-621 of 648 (95.8%)
# Results for Exp-621: Accuracy=78.05%, Recall=78.19%, F1=76.97%
# ----------------------------------------
# Running Exp-622 of 648 (96.0%)
# Results for Exp-622: Accuracy=69.13%, Recall=68.87%, F1=66.70%
# ----------------------------------------
# Running Exp-623 of 648 (96.1%)
# Results for Exp-623: Accuracy=76.21%, Recall=76.58%, F1=74.24%
# ----------------------------------------
# Running Exp-624 of 648 (96.3%)
# Results for Exp-624: Accuracy=79.18%, Recall=79.18%, F1=78.48%
# ----------------------------------------
# Running Exp-625 of 648 (96.5%)
# Results for Exp-625: Accuracy=85.45%, Recall=85.38%, F1=85.36%
# ----------------------------------------
# Running Exp-626 of 648 (96.6%)
# Results for Exp-626: Accuracy=86.58%, Recall=86.15%, F1=86.46%
# ----------------------------------------
# Running Exp-627 of 648 (96.8%)
# Results for Exp-627: Accuracy=87.38%, Recall=87.14%, F1=87.28%
# ----------------------------------------
# Running Exp-628 of 648 (96.9%)
# Results for Exp-628: Accuracy=86.09%, Recall=85.74%, F1=85.95%
# ----------------------------------------
# Running Exp-629 of 648 (97.1%)
# Results for Exp-629: Accuracy=88.10%, Recall=87.99%, F1=88.02%
# ----------------------------------------
# Running Exp-630 of 648 (97.2%)
# Results for Exp-630: Accuracy=87.78%, Recall=87.62%, F1=87.65%
# ----------------------------------------
# Running Exp-631 of 648 (97.4%)
# Results for Exp-631: Accuracy=84.32%, Recall=84.07%, F1=84.20%
# ----------------------------------------
# Running Exp-632 of 648 (97.5%)
# Results for Exp-632: Accuracy=86.50%, Recall=86.35%, F1=86.34%
# ----------------------------------------
# Running Exp-633 of 648 (97.7%)
# Results for Exp-633: Accuracy=85.21%, Recall=85.02%, F1=85.10%
# ----------------------------------------
# Running Exp-634 of 648 (97.8%)
# Results for Exp-634: Accuracy=85.21%, Recall=85.20%, F1=85.11%
# ----------------------------------------
# Running Exp-635 of 648 (98.0%)
# Results for Exp-635: Accuracy=87.46%, Recall=87.20%, F1=87.34%
# ----------------------------------------
# Running Exp-636 of 648 (98.1%)
# Results for Exp-636: Accuracy=85.93%, Recall=85.74%, F1=85.74%
# ----------------------------------------
# Running Exp-637 of 648 (98.3%)
# Results for Exp-637: Accuracy=82.96%, Recall=82.76%, F1=82.81%
# ----------------------------------------
# Running Exp-638 of 648 (98.5%)
# Results for Exp-638: Accuracy=84.73%, Recall=84.27%, F1=84.60%
# ----------------------------------------
# Running Exp-639 of 648 (98.6%)
# Results for Exp-639: Accuracy=85.45%, Recall=85.25%, F1=85.32%
# ----------------------------------------
# Running Exp-640 of 648 (98.8%)
# Results for Exp-640: Accuracy=84.08%, Recall=84.11%, F1=84.01%
# ----------------------------------------
# Running Exp-641 of 648 (98.9%)
# Results for Exp-641: Accuracy=86.25%, Recall=86.26%, F1=86.13%
# ----------------------------------------
# Running Exp-642 of 648 (99.1%)
# Results for Exp-642: Accuracy=86.09%, Recall=86.11%, F1=86.03%
# ----------------------------------------
# Running Exp-643 of 648 (99.2%)
# Results for Exp-643: Accuracy=79.90%, Recall=79.86%, F1=79.43%
# ----------------------------------------
# Running Exp-644 of 648 (99.4%)
# Results for Exp-644: Accuracy=82.72%, Recall=82.50%, F1=82.55%
# ----------------------------------------
# Running Exp-645 of 648 (99.5%)
# Results for Exp-645: Accuracy=82.80%, Recall=82.66%, F1=82.55%
# ----------------------------------------
# Running Exp-646 of 648 (99.7%)
# Results for Exp-646: Accuracy=77.65%, Recall=77.43%, F1=77.00%
# ----------------------------------------
# Running Exp-647 of 648 (99.8%)
# Results for Exp-647: Accuracy=82.72%, Recall=82.89%, F1=82.45%
# ----------------------------------------
# Running Exp-648 of 648 (100.0%)
# Results for Exp-648: Accuracy=85.37%, Recall=85.43%, F1=85.30%
# ----------------------------------------
# All experiments completed. Results saved to ../experiments/tuning/tuning_results_2.csv
#     Experiment  Number of Layers    Neurons per Layer  Learning Rate  \
# 0        Exp-1                 2            [128, 64]         0.0010
# 1        Exp-2                 2            [128, 64]         0.0010
# 2        Exp-3                 2            [128, 64]         0.0010
# 3        Exp-4                 2            [128, 64]         0.0010
# 4        Exp-5                 2            [128, 64]         0.0010
# ..         ...               ...                  ...            ...
# 643    Exp-644                 4  [512, 256, 128, 64]         0.0001
# 644    Exp-645                 4  [512, 256, 128, 64]         0.0001
# 645    Exp-646                 4  [512, 256, 128, 64]         0.0001
# 646    Exp-647                 4  [512, 256, 128, 64]         0.0001
# 647    Exp-648                 4  [512, 256, 128, 64]         0.0001
#
#      Dropout Rate  Batch Size  Epochs Optimizer  Accuracy  Recall  Value F1
# 0             0.3          16     100      Adam     81.43   81.29     81.38
# 1             0.3          16     200      Adam     81.75   81.41     81.59
# 2             0.3          16     300      Adam     81.75   81.58     81.56
# 3             0.3          32     100      Adam     84.57   84.54     84.42
# 4             0.3          32     200      Adam     84.32   84.11     84.18
# ..            ...         ...     ...       ...       ...     ...       ...
# 643           0.7          16     200      Adam     82.72   82.50     82.55
# 644           0.7          16     300      Adam     82.80   82.66     82.55
# 645           0.7          32     100      Adam     77.65   77.43     77.00
# 646           0.7          32     200      Adam     82.72   82.89     82.45
# 647           0.7          32     300      Adam     85.37   85.43     85.30
#
# [648 rows x 11 columns]
#
# Creating visualizations...
# Top 15 Configurations by Accuracy:
#     Experiment  Number of Layers    Neurons per Layer  Learning Rate  \
# 628    Exp-629                 4  [512, 256, 128, 64]         0.0001
# 557    Exp-558                 3      [512, 256, 128]         0.0001
# 629    Exp-630                 4  [512, 256, 128, 64]         0.0001
# 317    Exp-318                 3       [256, 128, 64]         0.0005
# 634    Exp-635                 4  [512, 256, 128, 64]         0.0001
# 626    Exp-627                 4  [512, 256, 128, 64]         0.0001
# 604    Exp-605                 4   [256, 128, 64, 32]         0.0001
# 533    Exp-534                 3       [256, 128, 64]         0.0001
# 485    Exp-486                 2           [512, 256]         0.0001
# 568    Exp-569                 3      [512, 256, 128]         0.0001
# 562    Exp-563                 3      [512, 256, 128]         0.0001
# 461    Exp-462                 2           [256, 128]         0.0001
# 490    Exp-491                 2           [512, 256]         0.0001
# 467    Exp-468                 2           [256, 128]         0.0001
# 322    Exp-323                 3       [256, 128, 64]         0.0005
#
#      Dropout Rate  Batch Size  Epochs Optimizer  Accuracy  Recall  Value F1
# 628           0.3          32     200      Adam     88.10   87.99     88.02
# 557           0.3          32     300      Adam     88.02   87.76     87.91
# 629           0.3          32     300      Adam     87.78   87.62     87.65
# 317           0.3          32     300      Adam     87.62   87.54     87.51
# 634           0.4          32     200      Adam     87.46   87.20     87.34
# 626           0.3          16     300      Adam     87.38   87.14     87.28
# 604           0.3          32     200      Adam     87.14   87.05     87.05
# 533           0.3          32     300      Adam     87.06   86.84     86.97
# 485           0.3          32     300      Adam     87.06   86.98     86.94
# 568           0.5          32     200      Adam     87.06   87.14     86.93
# 562           0.4          32     200      Adam     87.06   86.76     86.88
# 461           0.3          32     300      Adam     86.98   86.70     86.88
# 490           0.4          32     200      Adam     86.98   86.87     86.89
# 467           0.4          32     300      Adam     86.98   87.00     86.91
# 322           0.4          32     200      Adam     86.82   86.73     86.78
# Visualizations saved to ../experiments/tuning
#
# Top 5 configurations by accuracy:
#     Experiment  Number of Layers    Neurons per Layer  Learning Rate  \
# 628    Exp-629                 4  [512, 256, 128, 64]         0.0001
# 557    Exp-558                 3      [512, 256, 128]         0.0001
# 629    Exp-630                 4  [512, 256, 128, 64]         0.0001
# 317    Exp-318                 3       [256, 128, 64]         0.0005
# 634    Exp-635                 4  [512, 256, 128, 64]         0.0001
#
#      Dropout Rate  Batch Size  Epochs Optimizer  Accuracy  Recall  Value F1  \
# 628           0.3          32     200      Adam     88.10   87.99     88.02
# 557           0.3          32     300      Adam     88.02   87.76     87.91
# 629           0.3          32     300      Adam     87.78   87.62     87.65
# 317           0.3          32     300      Adam     87.62   87.54     87.51
# 634           0.4          32     200      Adam     87.46   87.20     87.34
#
#         Network Architecture
# 628  4L: [512, 256, 128, 64]
# 557      3L: [512, 256, 128]
# 629  4L: [512, 256, 128, 64]
# 317       3L: [256, 128, 64]
# 634  4L: [512, 256, 128, 64]
#
# Mean accuracy by parameter:
# Learning Rate: Learning Rate
# 0.0001    82.481204
# 0.0005    83.045741
# 0.0010    81.391574
# Name: Accuracy, dtype: float64
# Network Depth: Number of Layers
# 2    82.951481
# 3    82.789815
# 4    81.177222
# Name: Accuracy, dtype: float64
# Dropout Rate: Dropout Rate
# 0.3    84.333333
# 0.4    83.706728
# 0.5    82.590679
# 0.7    78.593951
# Name: Accuracy, dtype: float64
# Epochs: Epochs
# 100    81.588009
# 200    82.575278
# 300    82.755231
# Name: Accuracy, dtype: float64
